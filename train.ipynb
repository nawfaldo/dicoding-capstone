# %%
import pandas as pd
import numpy as np
import joblib
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, confusion_matrix, precision_recall_curve, roc_auc_score

# %%
raw_path = "dataset_raw.csv"
df = pd.read_csv(raw_path).drop_duplicates().dropna(how="all")

df.columns = df.columns.str.replace(r"[\[\]]", "", regex=True).str.replace(" ", "_")

df["quality"] = df["Product_ID"].str[0]
df["serial"] = df["Product_ID"].str[1:].astype(int)

if "UDI" in df.columns:
    df = df.drop(columns=["UDI"])
if "Product_ID" in df.columns:
    df = df.drop(columns=["Product_ID"])

y_binary = df['Target']
y_multi = df['Failure_Type']
X = df.drop(columns=['Target','Failure_Type'])

# %%
X = X.copy()

if 'process_temperature_K' in X.columns and 'air_temperature_K' in X.columns:
    X['temp_diff'] = X['process_temperature_K'] - X['air_temperature_K']
if 'torque_Nm' in X.columns and 'rotational_speed_rpm' in X.columns:
    X['load'] = X['torque_Nm'] * X['rotational_speed_rpm']
if 'load' in X.columns and 'process_temperature_K' in X.columns:
    X['stress'] = X['load'] / (X['process_temperature_K'] + 1e-9)
if 'tool_wear_min' in X.columns and 'serial' in X.columns:
    X['wear_rate'] = X['tool_wear_min'] / (X['serial'] + 1e-9)
if 'torque_Nm' in X.columns and 'process_temperature_K' in X.columns:
    X['torque_temp_inter'] = X['torque_Nm'] * X['process_temperature_K']

if 'rotational_speed_rpm' in X.columns:
    X['high_rpm'] = (X['rotational_speed_rpm'] > X['rotational_speed_rpm'].median()).astype(int)

X['quality_ord'] = X['quality'].map({'L':0, 'M':1, 'H':2})

# %%
cat_cols = X.select_dtypes(include=['object']).columns.tolist()
num_cols = X.select_dtypes(include=[np.number]).columns.tolist()

for c in cat_cols:
    X[c] = X[c].fillna(X[c].mode().iloc[0])
for c in num_cols:
    X[c] = X[c].fillna(X[c].median())

# %%
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y_binary, test_size=0.15, random_state=42, stratify=y_binary
)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.1764706, random_state=42, stratify=y_temp
)

# %%
categorical_features = [c for c in cat_cols if c in X_train.columns and c != 'quality']

if 'quality' in X_train.columns:
    categorical_features.append('quality')

numeric_features = [c for c in X_train.columns if c not in categorical_features]

numeric_transformer = StandardScaler()
cat_transformer = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', cat_transformer, categorical_features)
    ], remainder='drop'
)

# %%
scale_pos = (len(y_train) - y_train.sum()) / (y_train.sum() + 1e-9)


def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 200, 800),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 5.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'random_state': 42,
        'use_label_encoder': False,
        'verbosity': 0,
        'scale_pos_weight': scale_pos,
        'eval_metric': 'logloss'
    }

    model = XGBClassifier(**params)

    pipeline = ImbPipeline(steps=[
        ('pre', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('model', model)
    ])

    pipeline.fit(X_train, y_train)
    probs = pipeline.predict_proba(X_val)[:,1]

    prec, rec, th = precision_recall_curve(y_val, probs)
    f1s = 2 * (prec * rec) / (prec + rec + 1e-9)
    best_idx = np.nanargmax(f1s)
    best_f1 = f1s[best_idx]

    return best_f1

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=60, n_jobs=1)
print('Best params:', study.best_params)
# Out:
# [I 2025-11-15 14:34:16,802] A new study created in memory with name: no-name-8faaf011-d960-40e7-9bb8-f92c0b189d97
# [I 2025-11-15 14:34:17,349] Trial 0 finished with value: 0.7058823524611764 and parameters: {'n_estimators': 800, 'learning_rate': 0.024087434618909366, 'max_depth': 7, 'subsample': 0.9629085306405927, 'colsample_bytree': 0.7929265853236285, 'gamma': 1.2337289698883025, 'min_child_weight': 4}. Best is trial 0 with value: 0.7058823524611764.
# [I 2025-11-15 14:34:17,520] Trial 1 finished with value: 0.6913580242249657 and parameters: {'n_estimators': 454, 'learning_rate': 0.09121130830703934, 'max_depth': 5, 'subsample': 0.9983368365798114, 'colsample_bytree': 0.7257980602914909, 'gamma': 2.045341136481559, 'min_child_weight': 1}. Best is trial 0 with value: 0.7058823524611764.
# [I 2025-11-15 14:34:17,707] Trial 2 finished with value: 0.7021276590780897 and parameters: {'n_estimators': 354, 'learning_rate': 0.09385462160767698, 'max_depth': 5, 'subsample': 0.61268755549987, 'colsample_bytree': 0.6947247140072793, 'gamma': 0.7755023321761451, 'min_child_weight': 9}. Best is trial 0 with value: 0.7058823524611764.
# [I 2025-11-15 14:34:17,842] Trial 3 finished with value: 0.7272727267853822 and parameters: {'n_estimators': 274, 'learning_rate': 0.2677631212749219, 'max_depth': 8, 'subsample': 0.973139173022444, 'colsample_bytree': 0.8933235754326698, 'gamma': 0.3596855848466468, 'min_child_weight': 3}. Best is trial 3 with value: 0.7272727267853822.
# [I 2025-11-15 14:34:18,105] Trial 4 finished with value: 0.7422680407384419 and parameters: {'n_estimators': 341, 'learning_rate': 0.12155925778033949, 'max_depth': 8, 'subsample': 0.771037046905019, 'colsample_bytree': 0.6502275089097215, 'gamma': 0.11411225962028426, 'min_child_weight': 1}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:18,347] Trial 5 finished with value: 0.6896551719286563 and parameters: {'n_estimators': 311, 'learning_rate': 0.017028549177820953, 'max_depth': 7, 'subsample': 0.9717993317733622, 'colsample_bytree': 0.6168051969985595, 'gamma': 1.0320123024569117, 'min_child_weight': 9}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:18,634] Trial 6 finished with value: 0.7058823524611764 and parameters: {'n_estimators': 749, 'learning_rate': 0.26383957056193486, 'max_depth': 9, 'subsample': 0.9685864839758431, 'colsample_bytree': 0.8231322649806526, 'gamma': 0.19357008380955443, 'min_child_weight': 7}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:18,866] Trial 7 finished with value: 0.6136363631490185 and parameters: {'n_estimators': 634, 'learning_rate': 0.014619093112605414, 'max_depth': 3, 'subsample': 0.6194361808543671, 'colsample_bytree': 0.6412121945997358, 'gamma': 0.1954910481193367, 'min_child_weight': 10}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:19,023] Trial 8 finished with value: 0.7209302320754462 and parameters: {'n_estimators': 395, 'learning_rate': 0.09823136850304065, 'max_depth': 8, 'subsample': 0.6852050667808969, 'colsample_bytree': 0.8072575676807572, 'gamma': 4.39644542613039, 'min_child_weight': 1}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:19,292] Trial 9 finished with value: 0.7272727267853822 and parameters: {'n_estimators': 324, 'learning_rate': 0.043910561786938945, 'max_depth': 9, 'subsample': 0.6471793121597043, 'colsample_bytree': 0.6373069718958759, 'gamma': 1.4269493778688402, 'min_child_weight': 8}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:19,558] Trial 10 finished with value: 0.7311827952036072 and parameters: {'n_estimators': 563, 'learning_rate': 0.04634226787706288, 'max_depth': 10, 'subsample': 0.8115534263043911, 'colsample_bytree': 0.9397459723975284, 'gamma': 3.5281533608931523, 'min_child_weight': 5}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:19,841] Trial 11 finished with value: 0.7234042548227704 and parameters: {'n_estimators': 568, 'learning_rate': 0.042217625547768756, 'max_depth': 10, 'subsample': 0.7838692601301349, 'colsample_bytree': 0.9596725777584194, 'gamma': 3.618445440916974, 'min_child_weight': 5}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:19,966] Trial 12 finished with value: 0.7032967028040091 and parameters: {'n_estimators': 201, 'learning_rate': 0.1463875304961513, 'max_depth': 10, 'subsample': 0.8307082248646916, 'colsample_bytree': 0.9775435719797334, 'gamma': 3.3009794046573075, 'min_child_weight': 3}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:20,316] Trial 13 finished with value: 0.7126436776757826 and parameters: {'n_estimators': 520, 'learning_rate': 0.029045929611437434, 'max_depth': 9, 'subsample': 0.799372940367706, 'colsample_bytree': 0.8964949748849002, 'gamma': 2.734341245866576, 'min_child_weight': 6}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:20,527] Trial 14 finished with value: 0.6966292129938139 and parameters: {'n_estimators': 444, 'learning_rate': 0.06047847838648791, 'max_depth': 10, 'subsample': 0.8707249956539407, 'colsample_bytree': 0.7518106789954402, 'gamma': 4.88206655132749, 'min_child_weight': 2}. Best is trial 4 with value: 0.7422680407384419.
# [I 2025-11-15 14:34:20,750] Trial 15 finished with value: 0.7526881715476935 and parameters: {'n_estimators': 653, 'learning_rate': 0.16353777747459514, 'max_depth': 6, 'subsample': 0.728140763802247, 'colsample_bytree': 0.8765349114598671, 'gamma': 2.1832527982702334, 'min_child_weight': 5}. Best is trial 15 with value: 0.7526881715476935.
# [I 2025-11-15 14:34:20,978] Trial 16 finished with value: 0.7446808505674514 and parameters: {'n_estimators': 671, 'learning_rate': 0.15789644025519398, 'max_depth': 5, 'subsample': 0.7116039599561137, 'colsample_bytree': 0.864057272832151, 'gamma': 2.0537680085119527, 'min_child_weight': 3}. Best is trial 15 with value: 0.7526881715476935.
# [I 2025-11-15 14:34:21,203] Trial 17 finished with value: 0.7446808505674514 and parameters: {'n_estimators': 679, 'learning_rate': 0.17891284954174128, 'max_depth': 5, 'subsample': 0.728544199277741, 'colsample_bytree': 0.8690952467889822, 'gamma': 2.1027777440602735, 'min_child_weight': 4}. Best is trial 15 with value: 0.7526881715476935.
# [I 2025-11-15 14:34:21,439] Trial 18 finished with value: 0.7311827952036072 and parameters: {'n_estimators': 665, 'learning_rate': 0.19425833436056325, 'max_depth': 4, 'subsample': 0.7182662925238762, 'colsample_bytree': 0.8491940787191314, 'gamma': 1.8575200555505615, 'min_child_weight': 6}. Best is trial 15 with value: 0.7526881715476935.
# [I 2025-11-15 14:34:21,738] Trial 19 finished with value: 0.7333333328422222 and parameters: {'n_estimators': 722, 'learning_rate': 0.07517442675082295, 'max_depth': 6, 'subsample': 0.6794170996485706, 'colsample_bytree': 0.9242841691517176, 'gamma': 2.7596417774502613, 'min_child_weight': 3}. Best is trial 15 with value: 0.7526881715476935.
# [I 2025-11-15 14:34:22,141] Trial 20 finished with value: 0.7045454540581094 and parameters: {'n_estimators': 614, 'learning_rate': 0.010108794173148293, 'max_depth': 6, 'subsample': 0.8728074781991589, 'colsample_bytree': 0.7746788351468514, 'gamma': 2.43465184601666, 'min_child_weight': 4}. Best is trial 15 with value: 0.7526881715476935.
# [I 2025-11-15 14:34:22,370] Trial 21 finished with value: 0.7368421047658725 and parameters: {'n_estimators': 692, 'learning_rate': 0.17389572510896695, 'max_depth': 5, 'subsample': 0.7361237824391355, 'colsample_bytree': 0.8537380170708186, 'gamma': 2.0474762013725454, 'min_child_weight': 4}. Best is trial 15 with value: 0.7526881715476935.
# [I 2025-11-15 14:34:22,639] Trial 22 finished with value: 0.7608695647232986 and parameters: {'n_estimators': 775, 'learning_rate': 0.18984786704198614, 'max_depth': 4, 'subsample': 0.7352467925345256, 'colsample_bytree': 0.8765866793844521, 'gamma': 1.629051437461032, 'min_child_weight': 5}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:22,917] Trial 23 finished with value: 0.7446808505674514 and parameters: {'n_estimators': 797, 'learning_rate': 0.2951121853505454, 'max_depth': 3, 'subsample': 0.6842963173584163, 'colsample_bytree': 0.9010665021869617, 'gamma': 1.4939761195767143, 'min_child_weight': 7}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:23,157] Trial 24 finished with value: 0.7391304342885159 and parameters: {'n_estimators': 760, 'learning_rate': 0.12556878644251251, 'max_depth': 4, 'subsample': 0.7498180464204038, 'colsample_bytree': 0.8299575252213436, 'gamma': 3.1019776711112472, 'min_child_weight': 5}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:23,376] Trial 25 finished with value: 0.7499999995126548 and parameters: {'n_estimators': 612, 'learning_rate': 0.22579672965329864, 'max_depth': 4, 'subsample': 0.706055434135594, 'colsample_bytree': 0.9992978487516556, 'gamma': 1.6767704420535101, 'min_child_weight': 2}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:23,603] Trial 26 finished with value: 0.7356321834229091 and parameters: {'n_estimators': 603, 'learning_rate': 0.21241626291010401, 'max_depth': 4, 'subsample': 0.6480379080101917, 'colsample_bytree': 0.9919838637714252, 'gamma': 1.596438644813844, 'min_child_weight': 2}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:23,818] Trial 27 finished with value: 0.6966292129938139 and parameters: {'n_estimators': 531, 'learning_rate': 0.21920056659927079, 'max_depth': 3, 'subsample': 0.7539889084055889, 'colsample_bytree': 0.9397002212392608, 'gamma': 0.6594731985262923, 'min_child_weight': 7}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:24,110] Trial 28 finished with value: 0.7472527467600532 and parameters: {'n_estimators': 719, 'learning_rate': 0.12520980100573895, 'max_depth': 4, 'subsample': 0.8591640798516391, 'colsample_bytree': 0.9640924096401944, 'gamma': 0.92251161788909, 'min_child_weight': 6}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:24,398] Trial 29 finished with value: 0.7441860460289346 and parameters: {'n_estimators': 799, 'learning_rate': 0.06636021734746178, 'max_depth': 6, 'subsample': 0.9306708156763002, 'colsample_bytree': 0.9985768450657926, 'gamma': 1.6282002803221451, 'min_child_weight': 2}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:24,601] Trial 30 finished with value: 0.70103092733638 and parameters: {'n_estimators': 630, 'learning_rate': 0.23132965624357113, 'max_depth': 7, 'subsample': 0.7023958243369824, 'colsample_bytree': 0.9236413146736124, 'gamma': 2.4130834950490403, 'min_child_weight': 5}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:24,887] Trial 31 finished with value: 0.7272727267731863 and parameters: {'n_estimators': 722, 'learning_rate': 0.11944411828316277, 'max_depth': 4, 'subsample': 0.8411180491943555, 'colsample_bytree': 0.9498251248374829, 'gamma': 1.1479781897078958, 'min_child_weight': 6}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:25,165] Trial 32 finished with value: 0.7422680407384419 and parameters: {'n_estimators': 753, 'learning_rate': 0.12891255735284426, 'max_depth': 4, 'subsample': 0.9227022560183622, 'colsample_bytree': 0.9645991300764394, 'gamma': 0.9229656712815549, 'min_child_weight': 6}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:25,430] Trial 33 finished with value: 0.6881720425154353 and parameters: {'n_estimators': 704, 'learning_rate': 0.08591503654757816, 'max_depth': 3, 'subsample': 0.770392477888235, 'colsample_bytree': 0.9140344291914603, 'gamma': 0.6021752723216973, 'min_child_weight': 8}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:25,694] Trial 34 finished with value: 0.7391304342885159 and parameters: {'n_estimators': 651, 'learning_rate': 0.10444934205690341, 'max_depth': 4, 'subsample': 0.8718145433235167, 'colsample_bytree': 0.8796829562939905, 'gamma': 1.21709603316994, 'min_child_weight': 7}. Best is trial 22 with value: 0.7608695647232986.
# [I 2025-11-15 14:34:25,900] Trial 35 finished with value: 0.769230768738075 and parameters: {'n_estimators': 475, 'learning_rate': 0.1607341706633555, 'max_depth': 5, 'subsample': 0.6610008104305312, 'colsample_bytree': 0.9775141884659192, 'gamma': 1.6794750437072037, 'min_child_weight': 4}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:26,081] Trial 36 finished with value: 0.7199999995002 and parameters: {'n_estimators': 463, 'learning_rate': 0.24781784568409052, 'max_depth': 6, 'subsample': 0.6531625165030195, 'colsample_bytree': 0.7833533246493299, 'gamma': 1.8699825860057275, 'min_child_weight': 4}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:26,280] Trial 37 finished with value: 0.7446808505674514 and parameters: {'n_estimators': 479, 'learning_rate': 0.1503949341817932, 'max_depth': 5, 'subsample': 0.6089979034984995, 'colsample_bytree': 0.9981152135385989, 'gamma': 2.2923507566226125, 'min_child_weight': 4}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:26,437] Trial 38 finished with value: 0.7356321834229091 and parameters: {'n_estimators': 391, 'learning_rate': 0.29989139358475864, 'max_depth': 5, 'subsample': 0.6684181442214547, 'colsample_bytree': 0.6982551482612788, 'gamma': 1.7810651308032326, 'min_child_weight': 3}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:26,630] Trial 39 finished with value: 0.7555555550644444 and parameters: {'n_estimators': 585, 'learning_rate': 0.18650934885113082, 'max_depth': 7, 'subsample': 0.6329770852441575, 'colsample_bytree': 0.8345477078146097, 'gamma': 2.7084563175298, 'min_child_weight': 1}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:26,817] Trial 40 finished with value: 0.6987951802490927 and parameters: {'n_estimators': 559, 'learning_rate': 0.1888477642954755, 'max_depth': 7, 'subsample': 0.6300353685509223, 'colsample_bytree': 0.8291974694345343, 'gamma': 2.743872938255223, 'min_child_weight': 1}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:27,018] Trial 41 finished with value: 0.7272727267853822 and parameters: {'n_estimators': 594, 'learning_rate': 0.15882271619311736, 'max_depth': 7, 'subsample': 0.6960032639730368, 'colsample_bytree': 0.8004824107297575, 'gamma': 2.2651963633659693, 'min_child_weight': 1}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:27,237] Trial 42 finished with value: 0.7472527467600532 and parameters: {'n_estimators': 502, 'learning_rate': 0.23441727098656834, 'max_depth': 6, 'subsample': 0.6298306416090322, 'colsample_bytree': 0.882941208066017, 'gamma': 2.9749476889611612, 'min_child_weight': 2}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:27,448] Trial 43 finished with value: 0.6966292129938139 and parameters: {'n_estimators': 417, 'learning_rate': 0.1982070099172888, 'max_depth': 8, 'subsample': 0.6009460645210791, 'colsample_bytree': 0.8460266161506916, 'gamma': 1.4320739887304788, 'min_child_weight': 1}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:27,642] Trial 44 finished with value: 0.7333333328422222 and parameters: {'n_estimators': 535, 'learning_rate': 0.27004343788217067, 'max_depth': 6, 'subsample': 0.6706204580789905, 'colsample_bytree': 0.7588825077639247, 'gamma': 2.569046884972211, 'min_child_weight': 5}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:27,845] Trial 45 finished with value: 0.7272727267853822 and parameters: {'n_estimators': 584, 'learning_rate': 0.13980258122911285, 'max_depth': 7, 'subsample': 0.6587072912080303, 'colsample_bytree': 0.8126925668525923, 'gamma': 3.749129833199606, 'min_child_weight': 2}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:28,156] Trial 46 finished with value: 0.7446808505674514 and parameters: {'n_estimators': 640, 'learning_rate': 0.10726253206887061, 'max_depth': 5, 'subsample': 0.743291066998251, 'colsample_bytree': 0.9795574269998745, 'gamma': 1.320655689091207, 'min_child_weight': 3}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:28,348] Trial 47 finished with value: 0.6464646459651056 and parameters: {'n_estimators': 428, 'learning_rate': 0.027623680115040912, 'max_depth': 3, 'subsample': 0.7663750906649466, 'colsample_bytree': 0.900827316117347, 'gamma': 1.827266955158858, 'min_child_weight': 1}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:28,573] Trial 48 finished with value: 0.6999999995002001 and parameters: {'n_estimators': 497, 'learning_rate': 0.16752227071621326, 'max_depth': 5, 'subsample': 0.7214421888126619, 'colsample_bytree': 0.7237079222310175, 'gamma': 2.2085630128459304, 'min_child_weight': 5}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:28,863] Trial 49 finished with value: 0.7234042548227704 and parameters: {'n_estimators': 560, 'learning_rate': 0.08839884639413662, 'max_depth': 8, 'subsample': 0.6337576159865366, 'colsample_bytree': 0.9463757573650297, 'gamma': 2.595384347632366, 'min_child_weight': 4}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:29,205] Trial 50 finished with value: 0.7356321834229091 and parameters: {'n_estimators': 620, 'learning_rate': 0.03561440330935171, 'max_depth': 5, 'subsample': 0.6916626423328944, 'colsample_bytree': 0.9763594006639866, 'gamma': 2.9982301261830733, 'min_child_weight': 2}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:29,554] Trial 51 finished with value: 0.7333333328422222 and parameters: {'n_estimators': 777, 'learning_rate': 0.2063530823289945, 'max_depth': 4, 'subsample': 0.706905229511772, 'colsample_bytree': 0.9667291668211118, 'gamma': 1.028144250457257, 'min_child_weight': 6}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:29,877] Trial 52 finished with value: 0.7422680407384419 and parameters: {'n_estimators': 723, 'learning_rate': 0.11270219615874504, 'max_depth': 4, 'subsample': 0.8157499006140464, 'colsample_bytree': 0.931918383505107, 'gamma': 0.8456715810510164, 'min_child_weight': 5}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:30,229] Trial 53 finished with value: 0.7499999995019533 and parameters: {'n_estimators': 699, 'learning_rate': 0.13275228114127494, 'max_depth': 4, 'subsample': 0.7927675693868739, 'colsample_bytree': 0.957027804019425, 'gamma': 0.4914637426007875, 'min_child_weight': 8}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:30,530] Trial 54 finished with value: 0.7096774188595213 and parameters: {'n_estimators': 660, 'learning_rate': 0.1418714149179626, 'max_depth': 3, 'subsample': 0.8021271773295752, 'colsample_bytree': 0.906862971362073, 'gamma': 0.4516438994662417, 'min_child_weight': 9}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:30,929] Trial 55 finished with value: 0.7441860460289346 and parameters: {'n_estimators': 692, 'learning_rate': 0.1753392963249981, 'max_depth': 6, 'subsample': 0.783785110503672, 'colsample_bytree': 0.8773028469959506, 'gamma': 0.28698599383579154, 'min_child_weight': 9}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:31,320] Trial 56 finished with value: 0.7391304342885159 and parameters: {'n_estimators': 776, 'learning_rate': 0.24614054007177083, 'max_depth': 4, 'subsample': 0.7317029471044582, 'colsample_bytree': 0.9825091752986368, 'gamma': 0.08794780644538402, 'min_child_weight': 8}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:31,533] Trial 57 finished with value: 0.7294117642258823 and parameters: {'n_estimators': 740, 'learning_rate': 0.2718730407170881, 'max_depth': 5, 'subsample': 0.7853143495395181, 'colsample_bytree': 0.8378320647319872, 'gamma': 2.024916101117501, 'min_child_weight': 3}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:31,812] Trial 58 finished with value: 0.6966292129938139 and parameters: {'n_estimators': 678, 'learning_rate': 0.0520767269293314, 'max_depth': 5, 'subsample': 0.674572142890609, 'colsample_bytree': 0.864671079933728, 'gamma': 3.9306980118941928, 'min_child_weight': 10}. Best is trial 35 with value: 0.769230768738075.
# [I 2025-11-15 14:34:32,087] Trial 59 finished with value: 0.7209302320754462 and parameters: {'n_estimators': 575, 'learning_rate': 0.07692541081176697, 'max_depth': 6, 'subsample': 0.7573312638816699, 'colsample_bytree': 0.8125379066643793, 'gamma': 1.6740442956977022, 'min_child_weight': 4}. Best is trial 35 with value: 0.769230768738075.
# Best params: {'n_estimators': 475, 'learning_rate': 0.1607341706633555, 'max_depth': 5, 'subsample': 0.6610008104305312, 'colsample_bytree': 0.9775141884659192, 'gamma': 1.6794750437072037, 'min_child_weight': 4}

# %%
best_params = study.best_params
best_params.update({'random_state':42, 'use_label_encoder':False, 'verbosity':0, 'scale_pos_weight': scale_pos, 'eval_metric':'logloss'})

final_model = XGBClassifier(**best_params)
final_pipeline = ImbPipeline(steps=[
    ('pre', preprocessor),
    ('smote', SMOTE(random_state=42)),
    ('model', final_model)
])

X_comb = pd.concat([X_train, X_val])
y_comb = pd.concat([y_train, y_val])
final_pipeline.fit(X_comb, y_comb)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Air_temperature_K',
#                                                    'Process_temperature_K',
#                                                    'Rotational_speed_rpm',
#                                                    'Torque_Nm', 'Tool_wear_min',
#                                                    'serial', 'quality_ord']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Type', 'quality'])])),
#                 ('smote', SMOTE(random_state=42)),
#                 ('model',
#                  XGBCla...
#                                gamma=1.6794750437072037, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None,
#                                learning_rate=0.1607341706633555, max_bin=None,
#                                max_cat_threshold=None, max_cat_to_onehot=None,
#                                max_delta_step=None, max_depth=5,
#                                max_leaves=None, min_child_weight=4, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=475, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
probs_val = final_pipeline.predict_proba(X_val)[:,1]
prec, rec, th = precision_recall_curve(y_val, probs_val)
f1s = 2 * (prec * rec) / (prec + rec + 1e-9)
best_idx = np.nanargmax(f1s)
best_threshold = th[best_idx]
print('Best threshold (val):', best_threshold, 'Best F1 (val):', f1s[best_idx])
# Out:
# Best threshold (val): 0.9587665 Best F1 (val): 0.9999999995

# %%
probs_test = final_pipeline.predict_proba(X_test)[:,1]
final_pred = (probs_test >= best_threshold).astype(int)

print('\n=== Final classification report (test) ===')
print(classification_report(y_test, final_pred))
print('\nConfusion matrix:')
print(confusion_matrix(y_test, final_pred))
print('ROC AUC test:', roc_auc_score(y_test, probs_test))
# Out:
# === Final classification report (test) ===
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1449
#            1       0.76      0.86      0.81        51
#
#     accuracy                           0.99      1500
#    macro avg       0.88      0.93      0.90      1500
# weighted avg       0.99      0.99      0.99      1500
#
#
# Confusion matrix:
# [[1435   14]
#  [   7   44]]
# ROC AUC test: 0.9874423199231382

# %%
joblib.dump({'pipeline': final_pipeline, 'threshold': best_threshold, 'optuna_study': study}, 'model.pkl')
# Out:
# ['model.pkl']

# %%
df_raw = pd.read_csv(raw_path).drop_duplicates().dropna(how="all")

df_raw.columns = df_raw.columns.str.replace(r"[\[\]]", "", regex=True).str.replace(" ", "_")

df_raw_full = df_raw.copy()

df_raw_full = df_raw_full.reset_index(drop=True)

X_temp_raw, X_test_raw, y_temp_raw, y_test_raw_raw = train_test_split(
    df_raw_full, 
    df_raw_full["Target"], 
    test_size=0.15, 
    random_state=42, 
    stratify=df_raw_full["Target"]
)

inference_df = X_test_raw.copy()

inference_df.to_csv("inference.csv", index=False)

print("inference.csv berhasil dibuat!")
# Out:
# inference.csv berhasil dibuat!
