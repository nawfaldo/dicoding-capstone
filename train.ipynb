# %%
import pandas as pd
import numpy as np
import joblib
import optuna
from xgboost import XGBClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline as ImbPipeline
from imblearn.over_sampling import SMOTE
from sklearn.metrics import classification_report, precision_recall_curve
from sklearn.preprocessing import LabelEncoder

# %%
raw_path = "datasets/dataset_raw.csv"
df = pd.read_csv(raw_path).drop_duplicates().dropna(how="all")

df.columns = df.columns.str.replace(r"[\[\]]", "", regex=True).str.replace(" ", "_")

df["quality"] = df["Product_ID"].str[0]
df["serial"] = df["Product_ID"].str[1:].astype(int)

if "UDI" in df.columns:
    df = df.drop(columns=["UDI"])
if "Product_ID" in df.columns:
    df = df.drop(columns=["Product_ID"])

y_binary = df['Target']
y_multi = df['Failure_Type']
X = df.drop(columns=['Target','Failure_Type'])

# %%
X = X.copy()

if 'process_temperature_K' in X.columns and 'air_temperature_K' in X.columns:
    X['temp_diff'] = X['process_temperature_K'] - X['air_temperature_K']
if 'torque_Nm' in X.columns and 'rotational_speed_rpm' in X.columns:
    X['load'] = X['torque_Nm'] * X['rotational_speed_rpm']
if 'load' in X.columns and 'process_temperature_K' in X.columns:
    X['stress'] = X['load'] / (X['process_temperature_K'] + 1e-9)
if 'tool_wear_min' in X.columns and 'serial' in X.columns:
    X['wear_rate'] = X['tool_wear_min'] / (X['serial'] + 1e-9)
if 'torque_Nm' in X.columns and 'process_temperature_K' in X.columns:
    X['torque_temp_inter'] = X['torque_Nm'] * X['process_temperature_K']

if 'rotational_speed_rpm' in X.columns:
    X['high_rpm'] = (X['rotational_speed_rpm'] > X['rotational_speed_rpm'].median()).astype(int)

X['quality_ord'] = X['quality'].map({'L':0, 'M':1, 'H':2})

# %%
cat_cols = X.select_dtypes(include=['object']).columns.tolist()
num_cols = X.select_dtypes(include=[np.number]).columns.tolist()

for c in cat_cols:
    X[c] = X[c].fillna(X[c].mode().iloc[0])
for c in num_cols:
    X[c] = X[c].fillna(X[c].median())

# %%
X_temp, X_test, y_temp, y_test = train_test_split(
    X, y_binary, test_size=0.15, random_state=42, stratify=y_binary
)
X_train, X_val, y_train, y_val = train_test_split(
    X_temp, y_temp, test_size=0.1764706, random_state=42, stratify=y_temp
)

# %%
categorical_features = [c for c in cat_cols if c in X_train.columns and c != 'quality']

if 'quality' in X_train.columns:
    categorical_features.append('quality')

numeric_features = [c for c in X_train.columns if c not in categorical_features]

numeric_transformer = StandardScaler()
cat_transformer = OneHotEncoder(drop='first', sparse_output=False, handle_unknown='ignore')

preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', cat_transformer, categorical_features)
    ], remainder='drop'
)

# %%
scale_pos = (len(y_train) - y_train.sum()) / (y_train.sum() + 1e-9)

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 200, 800),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.3, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'gamma': trial.suggest_float('gamma', 0.0, 5.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'random_state': 42,
        'use_label_encoder': False,
        'verbosity': 0,
        'scale_pos_weight': scale_pos,
        'eval_metric': 'logloss'
    }

    model = XGBClassifier(**params)

    pipeline = ImbPipeline(steps=[
        ('pre', preprocessor),
        ('smote', SMOTE(random_state=42)),
        ('model', model)
    ])

    pipeline.fit(X_train, y_train)
    probs = pipeline.predict_proba(X_val)[:,1]

    prec, rec, th = precision_recall_curve(y_val, probs)
    f1s = 2 * (prec * rec) / (prec + rec + 1e-9)
    best_idx = np.nanargmax(f1s)
    best_f1 = f1s[best_idx]

    return best_f1

# %%
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=60, n_jobs=1)
print('Best params:', study.best_params)
# Out:
# [I 2025-11-19 00:26:03,854] A new study created in memory with name: no-name-2857bc22-bfad-44a4-bea0-7da9906fe057
# [I 2025-11-19 00:26:04,181] Trial 0 finished with value: 0.7142857138086735 and parameters: {'n_estimators': 755, 'learning_rate': 0.06582847322713758, 'max_depth': 4, 'subsample': 0.6007297703430753, 'colsample_bytree': 0.8431356874966419, 'gamma': 3.737105564528071, 'min_child_weight': 5}. Best is trial 0 with value: 0.7142857138086735.
# [I 2025-11-19 00:26:04,497] Trial 1 finished with value: 0.6999999995002001 and parameters: {'n_estimators': 726, 'learning_rate': 0.032723600669412364, 'max_depth': 4, 'subsample': 0.7668929332821297, 'colsample_bytree': 0.8745026351158875, 'gamma': 0.36365022167228034, 'min_child_weight': 5}. Best is trial 0 with value: 0.7142857138086735.
# [I 2025-11-19 00:26:04,743] Trial 2 finished with value: 0.7173913038537334 and parameters: {'n_estimators': 313, 'learning_rate': 0.020381133244332838, 'max_depth': 7, 'subsample': 0.7032427340846792, 'colsample_bytree': 0.9769719009925891, 'gamma': 3.5889651096258683, 'min_child_weight': 9}. Best is trial 2 with value: 0.7173913038537334.
# [I 2025-11-19 00:26:05,121] Trial 3 finished with value: 0.7356321834229091 and parameters: {'n_estimators': 560, 'learning_rate': 0.04300724975592786, 'max_depth': 8, 'subsample': 0.8057041752639296, 'colsample_bytree': 0.602847154836881, 'gamma': 1.3547202489574417, 'min_child_weight': 9}. Best is trial 3 with value: 0.7356321834229091.
# [I 2025-11-19 00:26:05,591] Trial 4 finished with value: 0.7333333328422222 and parameters: {'n_estimators': 640, 'learning_rate': 0.011684678274119167, 'max_depth': 7, 'subsample': 0.9132715592000122, 'colsample_bytree': 0.6520054173976376, 'gamma': 1.5854214622637586, 'min_child_weight': 9}. Best is trial 3 with value: 0.7356321834229091.
# [I 2025-11-19 00:26:05,727] Trial 5 finished with value: 0.652631578450083 and parameters: {'n_estimators': 260, 'learning_rate': 0.02186811303592934, 'max_depth': 4, 'subsample': 0.8129743951632316, 'colsample_bytree': 0.8435247989864958, 'gamma': 4.65980124261955, 'min_child_weight': 4}. Best is trial 3 with value: 0.7356321834229091.
# [I 2025-11-19 00:26:05,962] Trial 6 finished with value: 0.6976744181219577 and parameters: {'n_estimators': 646, 'learning_rate': 0.06383145893283305, 'max_depth': 7, 'subsample': 0.8315044755385286, 'colsample_bytree': 0.6263679150280033, 'gamma': 4.704906107755665, 'min_child_weight': 10}. Best is trial 3 with value: 0.7356321834229091.
# [I 2025-11-19 00:26:06,173] Trial 7 finished with value: 0.7391304342885159 and parameters: {'n_estimators': 455, 'learning_rate': 0.06326103146864656, 'max_depth': 7, 'subsample': 0.8426654968565096, 'colsample_bytree': 0.9535479589741892, 'gamma': 2.807673565000872, 'min_child_weight': 5}. Best is trial 7 with value: 0.7391304342885159.
# [I 2025-11-19 00:26:06,285] Trial 8 finished with value: 0.6199999995001999 and parameters: {'n_estimators': 208, 'learning_rate': 0.020767452008002202, 'max_depth': 4, 'subsample': 0.6066968996769929, 'colsample_bytree': 0.74895668927294, 'gamma': 1.1115265352587818, 'min_child_weight': 6}. Best is trial 7 with value: 0.7391304342885159.
# [I 2025-11-19 00:26:06,433] Trial 9 finished with value: 0.7126436776757826 and parameters: {'n_estimators': 362, 'learning_rate': 0.27436704684627844, 'max_depth': 3, 'subsample': 0.6474128005810316, 'colsample_bytree': 0.9572392710903772, 'gamma': 1.3142102102536906, 'min_child_weight': 5}. Best is trial 7 with value: 0.7391304342885159.
# [I 2025-11-19 00:26:06,610] Trial 10 finished with value: 0.7032967028040091 and parameters: {'n_estimators': 450, 'learning_rate': 0.14076529904092788, 'max_depth': 10, 'subsample': 0.9995154108673707, 'colsample_bytree': 0.7466158453470652, 'gamma': 2.7379270078987408, 'min_child_weight': 1}. Best is trial 7 with value: 0.7391304342885159.
# [I 2025-11-19 00:26:06,817] Trial 11 finished with value: 0.7356321834229091 and parameters: {'n_estimators': 517, 'learning_rate': 0.1008166528498166, 'max_depth': 9, 'subsample': 0.883539347482111, 'colsample_bytree': 0.7014712400216158, 'gamma': 2.5188072950659692, 'min_child_weight': 7}. Best is trial 7 with value: 0.7391304342885159.
# [I 2025-11-19 00:26:07,136] Trial 12 finished with value: 0.7472527467600532 and parameters: {'n_estimators': 505, 'learning_rate': 0.04183247414723998, 'max_depth': 9, 'subsample': 0.7556904390992066, 'colsample_bytree': 0.9261455724162009, 'gamma': 1.915630170458216, 'min_child_weight': 2}. Best is trial 12 with value: 0.7472527467600532.
# [I 2025-11-19 00:26:07,331] Trial 13 finished with value: 0.7446808505674514 and parameters: {'n_estimators': 423, 'learning_rate': 0.11174806807412584, 'max_depth': 9, 'subsample': 0.7232105538819921, 'colsample_bytree': 0.9136453061266809, 'gamma': 2.0825270567104326, 'min_child_weight': 2}. Best is trial 12 with value: 0.7472527467600532.
# [I 2025-11-19 00:26:07,513] Trial 14 finished with value: 0.7380952376181972 and parameters: {'n_estimators': 394, 'learning_rate': 0.1489208867337782, 'max_depth': 10, 'subsample': 0.7325338233271282, 'colsample_bytree': 0.8972515030688794, 'gamma': 1.9090885919975273, 'min_child_weight': 1}. Best is trial 12 with value: 0.7472527467600532.
# [I 2025-11-19 00:26:07,705] Trial 15 finished with value: 0.7333333328422222 and parameters: {'n_estimators': 564, 'learning_rate': 0.24345875570011868, 'max_depth': 9, 'subsample': 0.6901414708059973, 'colsample_bytree': 0.9211796990802461, 'gamma': 2.173713819236703, 'min_child_weight': 3}. Best is trial 12 with value: 0.7472527467600532.
# [I 2025-11-19 00:26:07,958] Trial 16 finished with value: 0.7157894731869251 and parameters: {'n_estimators': 401, 'learning_rate': 0.10125291412969481, 'max_depth': 9, 'subsample': 0.7515972172148957, 'colsample_bytree': 0.7952789831201854, 'gamma': 0.6838831348156036, 'min_child_weight': 2}. Best is trial 12 with value: 0.7472527467600532.
# [I 2025-11-19 00:26:08,255] Trial 17 finished with value: 0.7209302320754462 and parameters: {'n_estimators': 492, 'learning_rate': 0.0365742413559051, 'max_depth': 8, 'subsample': 0.6752498873004694, 'colsample_bytree': 0.9057839890807045, 'gamma': 3.165972751187606, 'min_child_weight': 3}. Best is trial 12 with value: 0.7472527467600532.
# [I 2025-11-19 00:26:08,564] Trial 18 finished with value: 0.7441860460289346 and parameters: {'n_estimators': 625, 'learning_rate': 0.0955304413539359, 'max_depth': 10, 'subsample': 0.7716575753448406, 'colsample_bytree': 0.993775061016585, 'gamma': 2.048810275200989, 'min_child_weight': 3}. Best is trial 12 with value: 0.7472527467600532.
# [I 2025-11-19 00:26:08,755] Trial 19 finished with value: 0.7356321834229091 and parameters: {'n_estimators': 326, 'learning_rate': 0.178175915587008, 'max_depth': 6, 'subsample': 0.7097060709823014, 'colsample_bytree': 0.8194095794658646, 'gamma': 0.8800718216864931, 'min_child_weight': 2}. Best is trial 12 with value: 0.7472527467600532.
# [I 2025-11-19 00:26:09,040] Trial 20 finished with value: 0.7191011231061734 and parameters: {'n_estimators': 569, 'learning_rate': 0.04896945298757375, 'max_depth': 6, 'subsample': 0.6446270157490794, 'colsample_bytree': 0.9328644960840636, 'gamma': 4.082257592067311, 'min_child_weight': 7}. Best is trial 12 with value: 0.7472527467600532.
# [I 2025-11-19 00:26:09,325] Trial 21 finished with value: 0.7619047614277211 and parameters: {'n_estimators': 645, 'learning_rate': 0.09793649799715745, 'max_depth': 10, 'subsample': 0.7720399962788242, 'colsample_bytree': 0.9963533146023291, 'gamma': 1.9232140192005087, 'min_child_weight': 3}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:09,641] Trial 22 finished with value: 0.7380952376181972 and parameters: {'n_estimators': 684, 'learning_rate': 0.0807553149807564, 'max_depth': 9, 'subsample': 0.781494115714864, 'colsample_bytree': 0.9935847419036441, 'gamma': 1.7225988205910587, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:09,826] Trial 23 finished with value: 0.7249999995378125 and parameters: {'n_estimators': 444, 'learning_rate': 0.134511186992931, 'max_depth': 8, 'subsample': 0.7415298642933315, 'colsample_bytree': 0.871804347437748, 'gamma': 2.33948904616691, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:09,997] Trial 24 finished with value: 0.7032967028040091 and parameters: {'n_estimators': 508, 'learning_rate': 0.20420816197256916, 'max_depth': 10, 'subsample': 0.8708335001255311, 'colsample_bytree': 0.9404104393572036, 'gamma': 2.8498223068851525, 'min_child_weight': 4}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:10,505] Trial 25 finished with value: 0.725274724782031 and parameters: {'n_estimators': 780, 'learning_rate': 0.07794095264975341, 'max_depth': 9, 'subsample': 0.7291237402377306, 'colsample_bytree': 0.9737147616015985, 'gamma': 0.22200897413790055, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:10,859] Trial 26 finished with value: 0.7209302320754462 and parameters: {'n_estimators': 597, 'learning_rate': 0.032778455714944026, 'max_depth': 8, 'subsample': 0.6668170030239188, 'colsample_bytree': 0.8797280424652397, 'gamma': 3.284250324941256, 'min_child_weight': 4}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:11,129] Trial 27 finished with value: 0.7228915657912613 and parameters: {'n_estimators': 703, 'learning_rate': 0.12041575293648638, 'max_depth': 10, 'subsample': 0.7856965528407847, 'colsample_bytree': 0.9994981583418298, 'gamma': 1.705478717628292, 'min_child_weight': 3}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:11,501] Trial 28 finished with value: 0.7126436776757826 and parameters: {'n_estimators': 531, 'learning_rate': 0.026893677492320977, 'max_depth': 9, 'subsample': 0.9263628299327495, 'colsample_bytree': 0.928287995767011, 'gamma': 2.384600752416277, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:11,739] Trial 29 finished with value: 0.7142857138086735 and parameters: {'n_estimators': 418, 'learning_rate': 0.052772331484375525, 'max_depth': 5, 'subsample': 0.7234977520769574, 'colsample_bytree': 0.843538131344209, 'gamma': 1.9955710777430176, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:12,387] Trial 30 finished with value: 0.7058823524611764 and parameters: {'n_estimators': 753, 'learning_rate': 0.013731577028959083, 'max_depth': 8, 'subsample': 0.833095978247764, 'colsample_bytree': 0.7800734532695401, 'gamma': 0.8930626117733058, 'min_child_weight': 4}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:12,645] Trial 31 finished with value: 0.7126436776757826 and parameters: {'n_estimators': 630, 'learning_rate': 0.08996871930998987, 'max_depth': 10, 'subsample': 0.7578761865515021, 'colsample_bytree': 0.9690027202829546, 'gamma': 2.0138996676178342, 'min_child_weight': 3}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:12,969] Trial 32 finished with value: 0.7294117642258823 and parameters: {'n_estimators': 679, 'learning_rate': 0.07035337852706788, 'max_depth': 10, 'subsample': 0.7651615557850414, 'colsample_bytree': 0.9975848250258984, 'gamma': 1.4675341696769886, 'min_child_weight': 3}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:13,203] Trial 33 finished with value: 0.6999999995378126 and parameters: {'n_estimators': 602, 'learning_rate': 0.10612047061860226, 'max_depth': 10, 'subsample': 0.7865832508005216, 'colsample_bytree': 0.9040470090941752, 'gamma': 2.5392460952944704, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:13,429] Trial 34 finished with value: 0.7126436776757826 and parameters: {'n_estimators': 723, 'learning_rate': 0.16477631578708138, 'max_depth': 9, 'subsample': 0.8056005183542635, 'colsample_bytree': 0.9578039428930293, 'gamma': 2.2065852699393638, 'min_child_weight': 3}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:13,775] Trial 35 finished with value: 0.7096774188595213 and parameters: {'n_estimators': 482, 'learning_rate': 0.04709577635507294, 'max_depth': 10, 'subsample': 0.6986360588256827, 'colsample_bytree': 0.869734587514267, 'gamma': 1.8068407863124583, 'min_child_weight': 6}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:14,035] Trial 36 finished with value: 0.7191011231061734 and parameters: {'n_estimators': 596, 'learning_rate': 0.05883622384865092, 'max_depth': 8, 'subsample': 0.7739263131844544, 'colsample_bytree': 0.9812685855146707, 'gamma': 3.146500269818011, 'min_child_weight': 4}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:14,451] Trial 37 finished with value: 0.7586206891700357 and parameters: {'n_estimators': 652, 'learning_rate': 0.03958776084520249, 'max_depth': 9, 'subsample': 0.7190678547736022, 'colsample_bytree': 0.9341826382786058, 'gamma': 1.21586602859881, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:14,793] Trial 38 finished with value: 0.7356321834229091 and parameters: {'n_estimators': 361, 'learning_rate': 0.03728464924214038, 'max_depth': 9, 'subsample': 0.716417792186105, 'colsample_bytree': 0.9143484170330278, 'gamma': 1.2790289386749671, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:15,387] Trial 39 finished with value: 0.7294117642258823 and parameters: {'n_estimators': 662, 'learning_rate': 0.026992005039611026, 'max_depth': 8, 'subsample': 0.613122712567573, 'colsample_bytree': 0.9448130523537915, 'gamma': 0.3949775698771494, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:15,813] Trial 40 finished with value: 0.7441860460289346 and parameters: {'n_estimators': 797, 'learning_rate': 0.04243637645971927, 'max_depth': 7, 'subsample': 0.6833753503028664, 'colsample_bytree': 0.8860353421149506, 'gamma': 1.490926465864209, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:16,086] Trial 41 finished with value: 0.7157894731869251 and parameters: {'n_estimators': 631, 'learning_rate': 0.11643899637000635, 'max_depth': 9, 'subsample': 0.7482523452223788, 'colsample_bytree': 0.9727695522929943, 'gamma': 1.0520217601964184, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:16,333] Trial 42 finished with value: 0.7228915657912613 and parameters: {'n_estimators': 556, 'learning_rate': 0.08145981745691769, 'max_depth': 10, 'subsample': 0.8195642113856012, 'colsample_bytree': 0.8519439854726927, 'gamma': 2.1498619056455497, 'min_child_weight': 3}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:16,641] Trial 43 finished with value: 0.7356321834229091 and parameters: {'n_estimators': 722, 'learning_rate': 0.06765422116298844, 'max_depth': 9, 'subsample': 0.8040666727807341, 'colsample_bytree': 0.9522455292762643, 'gamma': 1.600148785525189, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:17,194] Trial 44 finished with value: 0.7356321834229091 and parameters: {'n_estimators': 535, 'learning_rate': 0.02587736015711803, 'max_depth': 10, 'subsample': 0.8526984433190248, 'colsample_bytree': 0.9822874004037485, 'gamma': 0.6026996159364915, 'min_child_weight': 4}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:17,504] Trial 45 finished with value: 0.7045454540581094 and parameters: {'n_estimators': 272, 'learning_rate': 0.015296703424825106, 'max_depth': 9, 'subsample': 0.7101574961427596, 'colsample_bytree': 0.9320177737672175, 'gamma': 1.1918007935900574, 'min_child_weight': 8}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:17,775] Trial 46 finished with value: 0.6739130429841682 and parameters: {'n_estimators': 655, 'learning_rate': 0.06043399810011503, 'max_depth': 3, 'subsample': 0.6541550134334733, 'colsample_bytree': 0.9676071039361008, 'gamma': 1.9006860877452656, 'min_child_weight': 5}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:17,991] Trial 47 finished with value: 0.7294117642258823 and parameters: {'n_estimators': 464, 'learning_rate': 0.0926839447444545, 'max_depth': 10, 'subsample': 0.7605436712091079, 'colsample_bytree': 0.6976427933640742, 'gamma': 2.813107986659512, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:18,301] Trial 48 finished with value: 0.7333333328422222 and parameters: {'n_estimators': 623, 'learning_rate': 0.044091637180014756, 'max_depth': 8, 'subsample': 0.7365410399553022, 'colsample_bytree': 0.9149680041187138, 'gamma': 2.6554256356765986, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:18,507] Trial 49 finished with value: 0.7391304342885159 and parameters: {'n_estimators': 361, 'learning_rate': 0.11875231233672708, 'max_depth': 9, 'subsample': 0.6940110971535512, 'colsample_bytree': 0.8931162112673304, 'gamma': 1.4423154272324528, 'min_child_weight': 3}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:18,809] Trial 50 finished with value: 0.6956521734189508 and parameters: {'n_estimators': 754, 'learning_rate': 0.05565148731099795, 'max_depth': 10, 'subsample': 0.7857439563147385, 'colsample_bytree': 0.9557856720833404, 'gamma': 3.9059497917071067, 'min_child_weight': 10}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:19,227] Trial 51 finished with value: 0.7249999995378125 and parameters: {'n_estimators': 699, 'learning_rate': 0.03896414634854401, 'max_depth': 7, 'subsample': 0.6314749596583545, 'colsample_bytree': 0.8881806679672456, 'gamma': 1.4748546330408114, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:19,633] Trial 52 finished with value: 0.7356321834229091 and parameters: {'n_estimators': 762, 'learning_rate': 0.03161295194104058, 'max_depth': 5, 'subsample': 0.6704818097447575, 'colsample_bytree': 0.8232747318989238, 'gamma': 1.6377763155674634, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:20,025] Trial 53 finished with value: 0.7529411759905882 and parameters: {'n_estimators': 577, 'learning_rate': 0.031958504536338056, 'max_depth': 6, 'subsample': 0.6830832260357002, 'colsample_bytree': 0.9202728037248182, 'gamma': 2.0731606754016645, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:20,364] Trial 54 finished with value: 0.7058823524611764 and parameters: {'n_estimators': 579, 'learning_rate': 0.03192018923972259, 'max_depth': 6, 'subsample': 0.7443965672516443, 'colsample_bytree': 0.8593193303907135, 'gamma': 2.3023738909640907, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:20,794] Trial 55 finished with value: 0.7228915657912613 and parameters: {'n_estimators': 532, 'learning_rate': 0.017647476767478007, 'max_depth': 7, 'subsample': 0.718363989155626, 'colsample_bytree': 0.9413325822015796, 'gamma': 2.1414342526218237, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:20,964] Trial 56 finished with value: 0.7234042548227704 and parameters: {'n_estimators': 488, 'learning_rate': 0.20740381740447714, 'max_depth': 5, 'subsample': 0.7345707114832167, 'colsample_bytree': 0.9204345909348872, 'gamma': 2.4944953683525375, 'min_child_weight': 1}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:21,213] Trial 57 finished with value: 0.7073170727004758 and parameters: {'n_estimators': 613, 'learning_rate': 0.07290580692038737, 'max_depth': 9, 'subsample': 0.7040668210510972, 'colsample_bytree': 0.985263772569247, 'gamma': 2.96474870551011, 'min_child_weight': 3}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:21,390] Trial 58 finished with value: 0.7157894731869251 and parameters: {'n_estimators': 424, 'learning_rate': 0.1387595452439977, 'max_depth': 6, 'subsample': 0.766542116097744, 'colsample_bytree': 0.8281064598670163, 'gamma': 1.9777144532502398, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# [I 2025-11-19 00:26:21,667] Trial 59 finished with value: 0.7126436776757826 and parameters: {'n_estimators': 549, 'learning_rate': 0.02446844239393982, 'max_depth': 6, 'subsample': 0.995951568426794, 'colsample_bytree': 0.9622879851334553, 'gamma': 4.976358426951304, 'min_child_weight': 2}. Best is trial 21 with value: 0.7619047614277211.
# Best params: {'n_estimators': 645, 'learning_rate': 0.09793649799715745, 'max_depth': 10, 'subsample': 0.7720399962788242, 'colsample_bytree': 0.9963533146023291, 'gamma': 1.9232140192005087, 'min_child_weight': 3}

# %%
best_params = study.best_params
best_params.update({'random_state':42, 'use_label_encoder':False, 'verbosity':0, 'scale_pos_weight': scale_pos, 'eval_metric':'logloss'})

final_model = XGBClassifier(**best_params)
final_pipeline = ImbPipeline(steps=[
    ('pre', preprocessor),
    ('smote', SMOTE(random_state=42)),
    ('model', final_model)
])

X_comb = pd.concat([X_train, X_val])
y_comb = pd.concat([y_train, y_val])
final_pipeline.fit(X_comb, y_comb)

# %%
probs_val = final_pipeline.predict_proba(X_val)[:,1]
prec, rec, th = precision_recall_curve(y_val, probs_val)
f1s = 2 * (prec * rec) / (prec + rec + 1e-9)
best_idx = np.nanargmax(f1s)
best_threshold = th[best_idx]
print('Best threshold (val):', best_threshold, 'Best F1 (val):', f1s[best_idx])
# Out:
# Best threshold (val): 0.95347446 Best F1 (val): 0.9902912616359694

# %%
probs_test = final_pipeline.predict_proba(X_test)[:,1]
final_pred = (probs_test >= best_threshold).astype(int)

print('\n=== Final classification report (test) ===')
print(classification_report(y_test, final_pred))
# Out:
# === Final classification report (test) ===
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      1449
#            1       0.69      0.88      0.78        51
#
#     accuracy                           0.98      1500
#    macro avg       0.84      0.93      0.88      1500
# weighted avg       0.99      0.98      0.98      1500

# %%
joblib.dump({'pipeline': final_pipeline, 'threshold': best_threshold, 'optuna_study': study}, 'datasets/model.pkl')
# Out:
# ['model.pkl']

# %%
df_fail = df[df["Target"] == 1].reset_index(drop=True)

X_fail = X.loc[df["Target"] == 1].copy()
y_fail = df_fail["Failure_Type"].copy()

le = LabelEncoder()
y_fail_enc = le.fit_transform(y_fail)
num_classes = len(le.classes_)

X_train_m, X_test_m, y_train_m, y_test_m = train_test_split(
    X_fail,
    y_fail_enc,
    test_size=0.15,
    random_state=42,
    stratify=y_fail_enc
)

multi_model = XGBClassifier(
    objective="multi:softprob",
    num_class=num_classes,
    eval_metric="mlogloss",
    n_estimators=400,
    learning_rate=0.1,
    max_depth=6,
    subsample=0.9,
    colsample_bytree=0.9,
    random_state=42
)

multi_pipeline = ImbPipeline(steps=[
    ('pre', preprocessor),
    ('model', multi_model)
])

multi_pipeline.fit(X_train_m, y_train_m)
# Out:
# Pipeline(steps=[('pre',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Air_temperature_K',
#                                                    'Process_temperature_K',
#                                                    'Rotational_speed_rpm',
#                                                    'Torque_Nm', 'Tool_wear_min',
#                                                    'serial', 'quality_ord']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first',
#                                                                 handle_unknown='ignore',
#                                                                 sparse_output=False),
#                                                   ['Type', 'quality'])])),
#                 ('model',
#                  XGBClassifier(base_score=None, booster=N...
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.1,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=6, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=400, n_jobs=None, num_class=5, ...))])

# %%
probs_test_m = multi_pipeline.predict_proba(X_test_m)
final_pred_m = np.argmax(probs_test_m, axis=1)

target_names = le.classes_

print('\n=== Final classification report (test) ===')
print(classification_report(    
    y_test_m,
    final_pred_m,
    target_names=target_names
))
# Out:
# === Final classification report (test) ===
#                           precision    recall  f1-score   support
#
# Heat Dissipation Failure       0.89      1.00      0.94        17
#               No Failure       1.00      1.00      1.00         1
#       Overstrain Failure       0.86      0.50      0.63        12
#            Power Failure       0.82      1.00      0.90        14
#        Tool Wear Failure       0.86      0.86      0.86         7
#
#                 accuracy                           0.86        51
#                macro avg       0.89      0.87      0.87        51
#             weighted avg       0.86      0.86      0.85        51

# %%
joblib.dump({
    "pipeline": multi_pipeline,
    "label_encoder": le
}, "datasets/model_multiclass.pkl")
# Out:
# ['model_multiclass.pkl']

# %%
df_raw = pd.read_csv(raw_path).drop_duplicates().dropna(how="all")

df_raw.columns = df_raw.columns.str.replace(r"[\[\]]", "", regex=True).str.replace(" ", "_")

df_raw_full = df_raw.copy()

df_raw_full = df_raw_full.reset_index(drop=True)

X_temp_raw, X_test_raw, y_temp_raw, y_test_raw_raw = train_test_split(
    df_raw_full, 
    df_raw_full["Target"], 
    test_size=0.15, 
    random_state=42, 
    stratify=df_raw_full["Target"]
)

inference_df = X_test_raw.copy()

if 'Target' in inference_df.columns:
    inference_df = inference_df.drop(columns=['Target'])
if 'Failure_Type' in inference_df.columns:
    inference_df = inference_df.drop(columns=['Failure_Type'])

inference_df.to_csv("datasets/inference.csv", index=False)

inference_failure_df = X_test_raw[X_test_raw['Target'] == 1].copy()

if 'Target' in inference_failure_df.columns:
    inference_failure_df = inference_failure_df.drop(columns=['Target'])
if 'Failure_Type' in inference_failure_df.columns:
    inference_failure_df = inference_failure_df.drop(columns=['Failure_Type'])

inference_failure_df.to_csv("datasets/inference_failure.csv", index=False)

print("inference berhasil dibuat!")
# Out:
# inference berhasil dibuat!
