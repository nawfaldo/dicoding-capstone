# %%
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import pandas as pd

# %%
X_train = pd.read_pickle("dataset_preprocessed/X_train.pkl")
X_test = pd.read_pickle("dataset_preprocessed/X_test.pkl")
y_train_bin = pd.read_pickle("dataset_preprocessed/y_train_bin.pkl")
y_test_bin = pd.read_pickle("dataset_preprocessed/y_test_bin.pkl")

# %%
model_bin = XGBClassifier(
    n_estimators=500,
    max_depth=6,
    learning_rate=0.05,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    eval_metric='logloss',
    scale_pos_weight=(y_train_bin.value_counts()[0] / y_train_bin.value_counts()[1])
)

# %%
model_bin.fit(X_train, y_train_bin)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model_bin.fit(X_train, y_train_bin)
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\sklearn.py:1784, in XGBClassifier.fit(self, X, y, sample_weight, base_margin, eval_set, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights)
#    1781 model, feature_types = get_model_categories(X, model, self.feature_types)
#    1783 evals_result: EvalsLog = {}
# -> 1784 train_dmatrix, evals = _wrap_evaluation_matrices(
#    1785     missing=self.missing,
#    1786     X=X,
#    1787     y=y,
#    1788     group=None,
#    1789     qid=None,
#    1790     sample_weight=sample_weight,
#    1791     base_margin=base_margin,
#    1792     feature_weights=feature_weights,
#    1793     eval_set=eval_set,
#    1794     sample_weight_eval_set=sample_weight_eval_set,
#    1795     base_margin_eval_set=base_margin_eval_set,
#    1796     eval_group=None,
#    1797     eval_qid=None,
#    1798     create_dmatrix=self._create_dmatrix,
#    1799     enable_categorical=self.enable_categorical,
#    1800     feature_types=feature_types,
#    1801 )
#    1803 self._Booster = train(
#    1804     params,
#    1805     train_dmatrix,
#    (...)
#    1814     callbacks=self.callbacks,
#    1815 )
#    1817 if not callable(self.objective):
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\sklearn.py:701, in _wrap_evaluation_matrices(missing, X, y, group, qid, sample_weight, base_margin, feature_weights, eval_set, sample_weight_eval_set, base_margin_eval_set, eval_group, eval_qid, create_dmatrix, enable_categorical, feature_types)
#     696 """Convert array_like evaluation matrices into DMatrix. Perform sanity checks on the
#     697 way.
#     698
#     699 """
#     700 # Feature_types contains the optional reference categories from the booster object.
# --> 701 train_dmatrix = create_dmatrix(
#     702     data=X,
#     703     label=y,
#     704     group=group,
#     705     qid=qid,
#     706     weight=sample_weight,
#     707     base_margin=base_margin,
#     708     feature_weights=feature_weights,
#     709     missing=missing,
#     710     enable_categorical=enable_categorical,
#     711     feature_types=feature_types,
#     712     ref=None,
#     713 )
#     715 n_validation = 0 if eval_set is None else len(eval_set)
#     716 if hasattr(train_dmatrix, "get_categories"):
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\sklearn.py:1254, in XGBModel._create_dmatrix(self, ref, **kwargs)
#    1252 if _can_use_qdm(self.tree_method, self.device) and self.booster != "gblinear":
#    1253     try:
# -> 1254         return QuantileDMatrix(
#    1255             **kwargs, ref=ref, nthread=self.n_jobs, max_bin=self.max_bin
#    1256         )
#    1257     except TypeError:  # `QuantileDMatrix` supports lesser types than DMatrix
#    1258         pass
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:1768, in QuantileDMatrix.__init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread, max_bin, ref, group, qid, label_lower_bound, label_upper_bound, feature_weights, enable_categorical, max_quantile_batches, data_split_mode)
#    1748     if any(
#    1749         info is not None
#    1750         for info in (
#    (...)
#    1761         )
#    1762     ):
#    1763         raise ValueError(
#    1764             "If data iterator is used as input, data like label should be "
#    1765             "specified as batch argument."
#    1766         )
# -> 1768 self._init(
#    1769     data,
#    1770     ref=ref,
#    1771     label=label,
#    1772     weight=weight,
#    1773     base_margin=base_margin,
#    1774     group=group,
#    1775     qid=qid,
#    1776     label_lower_bound=label_lower_bound,
#    1777     label_upper_bound=label_upper_bound,
#    1778     feature_weights=feature_weights,
#    1779     feature_names=feature_names,
#    1780     feature_types=feature_types,
#    1781     enable_categorical=enable_categorical,
#    1782     max_quantile_blocks=max_quantile_batches,
#    1783 )
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:1832, in QuantileDMatrix._init(self, data, ref, enable_categorical, max_quantile_blocks, **meta)
#    1817 config = make_jcargs(
#    1818     nthread=self.nthread,
#    1819     missing=self.missing,
#    1820     max_bin=self.max_bin,
#    1821     max_quantile_blocks=max_quantile_blocks,
#    1822 )
#    1823 ret = _LIB.XGQuantileDMatrixCreateFromCallback(
#    1824     None,
#    1825     it.proxy.handle,
#    (...)
#    1830     ctypes.byref(handle),
#    1831 )
# -> 1832 it.reraise()
#    1833 # delay check_call to throw intermediate exception first
#    1834 _check_call(ret)
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:617, in DataIter.reraise(self)
#     615 exc = self._exception
#     616 self._exception = None
# --> 617 raise exc
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:598, in DataIter._handle_exception(self, fn, dft_ret)
#     595     return dft_ret
#     597 try:
# --> 598     return fn()
#     599 except Exception as e:  # pylint: disable=broad-except
#     600     # Defer the exception in order to return 0 and stop the iteration.
#     601     # Exception inside a ctype callback function has no effect except
#     602     # for printing to stderr (doesn't stop the execution).
#     603     tb = sys.exc_info()[2]
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:685, in DataIter._next_wrapper.<locals>.<lambda>()
#     683     self._temporary_data = None
#     684 # pylint: disable=not-callable
# --> 685 return self._handle_exception(lambda: int(self.next(input_data)), 0)
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\data.py:1632, in SingleBatchInternalIter.next(self, input_data)
#    1630     return False
#    1631 self.it += 1
# -> 1632 input_data(**self.kwargs)
#    1633 return True
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:674, in DataIter._next_wrapper.<locals>.input_data(data, feature_names, feature_types, **kwargs)
#     672 self._temporary_data = (new, feature_names, feature_types)
#     673 dispatch_proxy_set_data(self.proxy, new)
# --> 674 self.proxy.set_info(
#     675     feature_names=feature_names,
#     676     feature_types=feature_types,
#     677     **kwargs,
#     678 )
#     679 self._data_ref = ref
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:774, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     772 for k, arg in zip(sig.parameters, args):
#     773     kwargs[k] = arg
# --> 774 return func(**kwargs)
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:1089, in DMatrix.set_info(self, label, weight, base_margin, group, qid, label_lower_bound, label_upper_bound, feature_names, feature_types, feature_weights)
#    1087     self.set_float_info("label_upper_bound", label_upper_bound)
#    1088 if feature_names is not None:
# -> 1089     self.feature_names = feature_names
#    1090 if feature_types is not None:
#    1091     self.feature_types = feature_types
#
# File c:\Users\JawirGaming66\Code\dicoding\capstone\.venv\lib\site-packages\xgboost\core.py:1518, in DMatrix.feature_names(self, feature_names)
#    1513 # prohibit the use symbols that may affect parsing. e.g. []<
#    1514 if not all(
#    1515     isinstance(f, str) and not any(x in f for x in ["[", "]", "<"])
#    1516     for f in feature_names
#    1517 ):
# -> 1518     raise ValueError(
#    1519         "feature_names must be string, and may not contain [, ] or <"
#    1520     )
#    1522 feature_names_bytes = [bytes(f, encoding="utf-8") for f in feature_names]
#    1523 c_feature_names = (ctypes.c_char_p * len(feature_names_bytes))(
#    1524     *feature_names_bytes
#    1525 )
#
# ValueError: feature_names must be string, and may not contain [, ] or <

# %%
y_pred_bin = model_bin.predict(X_test)
