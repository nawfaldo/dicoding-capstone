# %%
import pandas as pd
import numpy as np
import optuna
import joblib


from xgboost import XGBClassifier
from sklearn.metrics import f1_score, classification_report, confusion_matrix, precision_recall_curve
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline as ImbPipeline

# %%
X_train = pd.read_pickle("dataset_preprocessed/X_train.pkl")
X_test = pd.read_pickle("dataset_preprocessed/X_test.pkl")
y_train_bin = pd.read_pickle("dataset_preprocessed/y_train_bin.pkl")
y_test_bin = pd.read_pickle("dataset_preprocessed/y_test_bin.pkl")

# %%
numeric_cols = X_train.columns

# %%
preprocessor = ColumnTransformer([
("num", StandardScaler(), numeric_cols)
])

# %%
def objective(trial):
    params = {
    "n_estimators": trial.suggest_int("n_estimators", 200, 800),
    "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
    "max_depth": trial.suggest_int("max_depth", 3, 12),
    "subsample": trial.suggest_float("subsample", 0.5, 1.0),
    "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
    "gamma": trial.suggest_float("gamma", 0, 5),
    "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
    "random_state": 42,
    "eval_metric": "logloss",
    "scale_pos_weight": (len(y_train_bin) - y_train_bin.sum()) / y_train_bin.sum()
    }


    xgb_model = XGBClassifier(**params)


    pipeline = ImbPipeline(steps=[
    ("scale", preprocessor),
    ("smote", SMOTE(random_state=42)),
    ("model", xgb_model)
    ])


    pipeline.fit(X_train, y_train_bin)
    probs = pipeline.predict_proba(X_test)[:, 1]


    prec, rec, th = precision_recall_curve(y_test_bin, probs)
    f1_scores = 2 * (prec * rec) / (prec + rec + 1e-9)
    best_idx = np.argmax(f1_scores)


    return f1_scores[best_idx]

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=40)


print("Best Trial Params:", study.best_trial.params)
# Out:
# [I 2025-11-15 13:44:39,725] A new study created in memory with name: no-name-dddd9388-303f-4ce7-8204-f95021d0e94e
# [I 2025-11-15 13:44:40,270] Trial 0 finished with value: 0.7586206891700357 and parameters: {'n_estimators': 614, 'learning_rate': 0.038375985900929, 'max_depth': 10, 'subsample': 0.8045453560567064, 'colsample_bytree': 0.9497204178682787, 'gamma': 1.8534457662483095, 'min_child_weight': 2}. Best is trial 0 with value: 0.7586206891700357.
# [I 2025-11-15 13:44:40,426] Trial 1 finished with value: 0.7310344822605469 and parameters: {'n_estimators': 241, 'learning_rate': 0.22470065192009245, 'max_depth': 8, 'subsample': 0.5624588593596962, 'colsample_bytree': 0.6038403965936823, 'gamma': 1.7140382622158412, 'min_child_weight': 9}. Best is trial 0 with value: 0.7586206891700357.
# [I 2025-11-15 13:44:40,538] Trial 2 finished with value: 0.7301587296618796 and parameters: {'n_estimators': 325, 'learning_rate': 0.24664487301269927, 'max_depth': 6, 'subsample': 0.8247682739971789, 'colsample_bytree': 0.8189781916301027, 'gamma': 3.2497070007729634, 'min_child_weight': 1}. Best is trial 0 with value: 0.7586206891700357.
# [I 2025-11-15 13:44:40,856] Trial 3 finished with value: 0.7213114749164202 and parameters: {'n_estimators': 778, 'learning_rate': 0.032771783242425606, 'max_depth': 4, 'subsample': 0.9133020228464652, 'colsample_bytree': 0.5641799870525036, 'gamma': 2.709679086933636, 'min_child_weight': 10}. Best is trial 0 with value: 0.7586206891700357.
# [I 2025-11-15 13:44:41,216] Trial 4 finished with value: 0.7460317455348954 and parameters: {'n_estimators': 649, 'learning_rate': 0.046759072485230965, 'max_depth': 4, 'subsample': 0.5512438867299192, 'colsample_bytree': 0.8228478984052097, 'gamma': 3.1119511194558576, 'min_child_weight': 3}. Best is trial 0 with value: 0.7586206891700357.
# [I 2025-11-15 13:44:41,415] Trial 5 finished with value: 0.7166666661755554 and parameters: {'n_estimators': 513, 'learning_rate': 0.19309117388885086, 'max_depth': 8, 'subsample': 0.9732334736374741, 'colsample_bytree': 0.607408905186713, 'gamma': 3.2422244208773026, 'min_child_weight': 2}. Best is trial 0 with value: 0.7586206891700357.
# [I 2025-11-15 13:44:41,702] Trial 6 finished with value: 0.7286821700441078 and parameters: {'n_estimators': 543, 'learning_rate': 0.047301451290405735, 'max_depth': 3, 'subsample': 0.8748722135328639, 'colsample_bytree': 0.854057884486433, 'gamma': 0.9778723058968003, 'min_child_weight': 8}. Best is trial 0 with value: 0.7586206891700357.
# [I 2025-11-15 13:44:42,237] Trial 7 finished with value: 0.7338129491405208 and parameters: {'n_estimators': 703, 'learning_rate': 0.09267206005157405, 'max_depth': 12, 'subsample': 0.6252753234919468, 'colsample_bytree': 0.887941415437087, 'gamma': 0.49946080649918845, 'min_child_weight': 5}. Best is trial 0 with value: 0.7586206891700357.
# [I 2025-11-15 13:44:42,471] Trial 8 finished with value: 0.7656249995019532 and parameters: {'n_estimators': 456, 'learning_rate': 0.23204888364251527, 'max_depth': 3, 'subsample': 0.8234206549506682, 'colsample_bytree': 0.9214054524264952, 'gamma': 2.770497601389954, 'min_child_weight': 1}. Best is trial 8 with value: 0.7656249995019532.
# [I 2025-11-15 13:44:42,684] Trial 9 finished with value: 0.7627118639184142 and parameters: {'n_estimators': 643, 'learning_rate': 0.13556132738194868, 'max_depth': 12, 'subsample': 0.817020680491602, 'colsample_bytree': 0.9102639042599155, 'gamma': 3.2694123432265543, 'min_child_weight': 5}. Best is trial 8 with value: 0.7656249995019532.
# [I 2025-11-15 13:44:42,820] Trial 10 finished with value: 0.7679999995038719 and parameters: {'n_estimators': 368, 'learning_rate': 0.2977612983179687, 'max_depth': 6, 'subsample': 0.6946056646710245, 'colsample_bytree': 0.70865856406707, 'gamma': 4.899715075547695, 'min_child_weight': 7}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:42,957] Trial 11 finished with value: 0.7424242419247014 and parameters: {'n_estimators': 390, 'learning_rate': 0.29395190987727876, 'max_depth': 6, 'subsample': 0.7039905071153363, 'colsample_bytree': 0.6984614666196576, 'gamma': 4.909380748678018, 'min_child_weight': 7}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:43,098] Trial 12 finished with value: 0.7317073165787561 and parameters: {'n_estimators': 420, 'learning_rate': 0.296828686558533, 'max_depth': 6, 'subsample': 0.692102809553641, 'colsample_bytree': 0.7180050314594479, 'gamma': 4.9688636893185185, 'min_child_weight': 6}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:43,254] Trial 13 finished with value: 0.7412587407599394 and parameters: {'n_estimators': 406, 'learning_rate': 0.2434755583032343, 'max_depth': 3, 'subsample': 0.7316883650950935, 'colsample_bytree': 0.9940046555420772, 'gamma': 4.190390764747556, 'min_child_weight': 4}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:43,369] Trial 14 finished with value: 0.7162162157195032 and parameters: {'n_estimators': 204, 'learning_rate': 0.1880442630634135, 'max_depth': 5, 'subsample': 0.6431113960640507, 'colsample_bytree': 0.7627900229513978, 'gamma': 4.034891459962269, 'min_child_weight': 7}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:43,488] Trial 15 finished with value: 0.752136751649938 and parameters: {'n_estimators': 289, 'learning_rate': 0.26352913976184356, 'max_depth': 10, 'subsample': 0.7622487776743092, 'colsample_bytree': 0.6620603391742915, 'gamma': 4.080653700005062, 'min_child_weight': 4}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:43,655] Trial 16 finished with value: 0.7338129491405208 and parameters: {'n_estimators': 464, 'learning_rate': 0.20151608984196698, 'max_depth': 7, 'subsample': 0.9177835515285914, 'colsample_bytree': 0.770692583940187, 'gamma': 2.016672718823913, 'min_child_weight': 7}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:43,821] Trial 17 finished with value: 0.7482014383491538 and parameters: {'n_estimators': 333, 'learning_rate': 0.14593867506313307, 'max_depth': 4, 'subsample': 0.6359016158761145, 'colsample_bytree': 0.501088850111048, 'gamma': 1.319643686245663, 'min_child_weight': 1}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:44,017] Trial 18 finished with value: 0.7222222217237654 and parameters: {'n_estimators': 554, 'learning_rate': 0.2785763684648856, 'max_depth': 9, 'subsample': 0.7668426518879559, 'colsample_bytree': 0.6706967634984548, 'gamma': 2.434993748652158, 'min_child_weight': 9}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:44,295] Trial 19 finished with value: 0.7194244599318875 and parameters: {'n_estimators': 473, 'learning_rate': 0.2229342489754932, 'max_depth': 5, 'subsample': 0.5054039937342292, 'colsample_bytree': 0.992705157891083, 'gamma': 0.0997374068136212, 'min_child_weight': 6}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:44,437] Trial 20 finished with value: 0.7559055113135346 and parameters: {'n_estimators': 366, 'learning_rate': 0.1639717244535637, 'max_depth': 7, 'subsample': 0.852763036385467, 'colsample_bytree': 0.8132785392601809, 'gamma': 4.480151476853845, 'min_child_weight': 4}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:44,653] Trial 21 finished with value: 0.7666666661755555 and parameters: {'n_estimators': 611, 'learning_rate': 0.12773366246389295, 'max_depth': 12, 'subsample': 0.7894344762201424, 'colsample_bytree': 0.909953885375078, 'gamma': 3.636916643071309, 'min_child_weight': 5}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:44,892] Trial 22 finished with value: 0.735999999503872 and parameters: {'n_estimators': 575, 'learning_rate': 0.10614640508809647, 'max_depth': 11, 'subsample': 0.7778306813635074, 'colsample_bytree': 0.9074103382834455, 'gamma': 3.530244859029156, 'min_child_weight': 8}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:45,111] Trial 23 finished with value: 0.7518796987483748 and parameters: {'n_estimators': 450, 'learning_rate': 0.11144784118525622, 'max_depth': 9, 'subsample': 0.685164779095011, 'colsample_bytree': 0.9327289897111398, 'gamma': 2.4369683358570486, 'min_child_weight': 3}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:45,334] Trial 24 finished with value: 0.7536231879059021 and parameters: {'n_estimators': 730, 'learning_rate': 0.16824312690959742, 'max_depth': 5, 'subsample': 0.8670567418921702, 'colsample_bytree': 0.8576330633573552, 'gamma': 3.678556228675041, 'min_child_weight': 6}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:45,566] Trial 25 finished with value: 0.7258064511175858 and parameters: {'n_estimators': 511, 'learning_rate': 0.26611753963007906, 'max_depth': 3, 'subsample': 0.725526976108348, 'colsample_bytree': 0.950605137514067, 'gamma': 4.529707910984035, 'min_child_weight': 8}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:45,828] Trial 26 finished with value: 0.7580645156337149 and parameters: {'n_estimators': 589, 'learning_rate': 0.07814409671412442, 'max_depth': 11, 'subsample': 0.6657009879063139, 'colsample_bytree': 0.7331139522016258, 'gamma': 2.7561943492841445, 'min_child_weight': 2}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:45,977] Trial 27 finished with value: 0.7538461533472189 and parameters: {'n_estimators': 352, 'learning_rate': 0.13300277309905845, 'max_depth': 9, 'subsample': 0.9208858782483527, 'colsample_bytree': 0.8634835466679313, 'gamma': 3.7587033840507797, 'min_child_weight': 5}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:46,325] Trial 28 finished with value: 0.7111111106111385 and parameters: {'n_estimators': 432, 'learning_rate': 0.010120820120785523, 'max_depth': 7, 'subsample': 0.7906736905638909, 'colsample_bytree': 0.7691755781824428, 'gamma': 4.509953349547674, 'min_child_weight': 3}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:46,464] Trial 29 finished with value: 0.7350427345559208 and parameters: {'n_estimators': 287, 'learning_rate': 0.2189227329523336, 'max_depth': 10, 'subsample': 0.7397994435283778, 'colsample_bytree': 0.9539158865549695, 'gamma': 2.8348826310380697, 'min_child_weight': 2}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:46,720] Trial 30 finished with value: 0.731343283082201 and parameters: {'n_estimators': 631, 'learning_rate': 0.24268676434802097, 'max_depth': 4, 'subsample': 0.5969152020653475, 'colsample_bytree': 0.8025912158021211, 'gamma': 1.9882650393379466, 'min_child_weight': 10}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:46,954] Trial 31 finished with value: 0.764227641782008 and parameters: {'n_estimators': 707, 'learning_rate': 0.1267586348772046, 'max_depth': 12, 'subsample': 0.8143738630969759, 'colsample_bytree': 0.9192983219712261, 'gamma': 3.505327261762352, 'min_child_weight': 5}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:47,163] Trial 32 finished with value: 0.7627118639184142 and parameters: {'n_estimators': 685, 'learning_rate': 0.17236466391743135, 'max_depth': 11, 'subsample': 0.8285460690171746, 'colsample_bytree': 0.9684894408928105, 'gamma': 3.860273884837089, 'min_child_weight': 7}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:47,422] Trial 33 finished with value: 0.7445255469452822 and parameters: {'n_estimators': 788, 'learning_rate': 0.11581508362078347, 'max_depth': 12, 'subsample': 0.7994297627135566, 'colsample_bytree': 0.8856353841655558, 'gamma': 3.468135690334653, 'min_child_weight': 6}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:47,693] Trial 34 finished with value: 0.7412587407599394 and parameters: {'n_estimators': 739, 'learning_rate': 0.09152511607806263, 'max_depth': 11, 'subsample': 0.8527561132843758, 'colsample_bytree': 0.9212698037986488, 'gamma': 2.9136475790048113, 'min_child_weight': 9}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:47,910] Trial 35 finished with value: 0.7272727267731863 and parameters: {'n_estimators': 692, 'learning_rate': 0.1492293580219497, 'max_depth': 8, 'subsample': 0.8912599800311989, 'colsample_bytree': 0.6472716702723806, 'gamma': 2.194365147090502, 'min_child_weight': 1}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:48,282] Trial 36 finished with value: 0.7499999995 and parameters: {'n_estimators': 753, 'learning_rate': 0.0704543676044697, 'max_depth': 12, 'subsample': 0.9608839241052111, 'colsample_bytree': 0.8376647321049716, 'gamma': 1.4063235514566177, 'min_child_weight': 4}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:48,489] Trial 37 finished with value: 0.7457627113760413 and parameters: {'n_estimators': 599, 'learning_rate': 0.1317020133610043, 'max_depth': 6, 'subsample': 0.8317137290558547, 'colsample_bytree': 0.790582308376225, 'gamma': 2.983708764513604, 'min_child_weight': 5}. Best is trial 10 with value: 0.7679999995038719.
# [I 2025-11-15 13:44:48,657] Trial 38 finished with value: 0.793650793153943 and parameters: {'n_estimators': 495, 'learning_rate': 0.20836540412690088, 'max_depth': 10, 'subsample': 0.7987173142869121, 'colsample_bytree': 0.8801431868276532, 'gamma': 3.371646451399516, 'min_child_weight': 3}. Best is trial 38 with value: 0.793650793153943.
# [I 2025-11-15 13:44:48,832] Trial 39 finished with value: 0.7419354833756504 and parameters: {'n_estimators': 490, 'learning_rate': 0.20842682545647967, 'max_depth': 8, 'subsample': 0.7135738300071786, 'colsample_bytree': 0.8738554287704118, 'gamma': 2.619972273446648, 'min_child_weight': 1}. Best is trial 38 with value: 0.793650793153943.
# Best Trial Params: {'n_estimators': 495, 'learning_rate': 0.20836540412690088, 'max_depth': 10, 'subsample': 0.7987173142869121, 'colsample_bytree': 0.8801431868276532, 'gamma': 3.371646451399516, 'min_child_weight': 3}

# %%
best_params = study.best_params
best_params["random_state"] = 42
best_params["eval_metric"] = "logloss"
best_params["scale_pos_weight"] = (len(y_train_bin) - y_train_bin.sum()) / y_train_bin.sum()

# %%
best_model = XGBClassifier(**best_params)

# %%
pipeline_best = ImbPipeline(steps=[
    ("scale", preprocessor),
    ("smote", SMOTE(random_state=42)),
    ("model", best_model)
])

# %%
pipeline_best.fit(X_train, y_train_bin)
probs = pipeline_best.predict_proba(X_test)[:, 1]

# %%
prec, rec, thresholds = precision_recall_curve(y_test_bin, probs)
f1_scores = 2 * (prec * rec) / (prec + rec + 1e-9)
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]

# %%
print("Best Threshold:", best_threshold)
print("Best F1 Score:", f1_scores[best_idx])
# Out:
# Best Threshold: 0.99300134
# Best F1 Score: 0.793650793153943

# %%
final_pred = (probs >= best_threshold).astype(int)

# %%
print("\n=== Classification Report ===")
print(classification_report(y_test_bin, final_pred))


print("\n=== Confusion Matrix ===")
print(confusion_matrix(y_test_bin, final_pred))
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99      1932
#            1       0.86      0.74      0.79        68
#
#     accuracy                           0.99      2000
#    macro avg       0.93      0.87      0.89      2000
# weighted avg       0.99      0.99      0.99      2000
#
#
# === Confusion Matrix ===
# [[1924    8]
#  [  18   50]]
