# %%
import pandas as pd
import numpy as np
import optuna
import joblib

from xgboost import XGBClassifier
from sklearn.metrics import f1_score, classification_report, confusion_matrix
from imblearn.over_sampling import SMOTE
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.compose import ColumnTransformer
from imblearn.pipeline import Pipeline as ImbPipeline

# %%
X_train = pd.read_pickle("dataset_preprocessed/X_train.pkl")
X_test = pd.read_pickle("dataset_preprocessed/X_test.pkl")
y_train_bin = pd.read_pickle("dataset_preprocessed/y_train_bin.pkl")
y_test_bin = pd.read_pickle("dataset_preprocessed/y_test_bin.pkl")

# %%
numeric_cols = X_train.columns

# %%
preprocessor = ColumnTransformer([
    ("num", StandardScaler(), numeric_cols)
])

# %%
def objective(trial):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 200, 800),
        "learning_rate": trial.suggest_float("learning_rate", 0.01, 0.3),
        "max_depth": trial.suggest_int("max_depth", 3, 12),
        "subsample": trial.suggest_float("subsample", 0.5, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.5, 1.0),
        "gamma": trial.suggest_float("gamma", 0, 5),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 10),
        "random_state": 42,
        "eval_metric": "logloss",
        "scale_pos_weight": (len(y_train_bin) - y_train_bin.sum()) / y_train_bin.sum()
    }

    xgb_model = XGBClassifier(**params)

    pipeline = ImbPipeline(steps=[
        ("scale", preprocessor),
        ("smote", SMOTE(random_state=42)),
        ("model", xgb_model)
    ])

    pipeline.fit(X_train, y_train_bin)
    preds = pipeline.predict(X_test)

    return f1_score(y_test_bin, preds)

# %%
study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=40)
# Out:
# [I 2025-11-15 13:41:09,687] A new study created in memory with name: no-name-8d26d9bd-0f6d-409b-b821-03ff9fb1316f
# [I 2025-11-15 13:41:10,269] Trial 0 finished with value: 0.4236111111111111 and parameters: {'n_estimators': 443, 'learning_rate': 0.08194414008649754, 'max_depth': 4, 'subsample': 0.8529971585690839, 'colsample_bytree': 0.5448930933615466, 'gamma': 2.0339864350522117, 'min_child_weight': 2}. Best is trial 0 with value: 0.4236111111111111.
# [I 2025-11-15 13:41:10,460] Trial 1 finished with value: 0.449438202247191 and parameters: {'n_estimators': 329, 'learning_rate': 0.08955054746611865, 'max_depth': 11, 'subsample': 0.8998456340639869, 'colsample_bytree': 0.5506199586716556, 'gamma': 4.710287589722148, 'min_child_weight': 4}. Best is trial 1 with value: 0.449438202247191.
# [I 2025-11-15 13:41:10,664] Trial 2 finished with value: 0.5128205128205128 and parameters: {'n_estimators': 437, 'learning_rate': 0.2821300436987093, 'max_depth': 4, 'subsample': 0.5720958007998747, 'colsample_bytree': 0.7644030307276559, 'gamma': 3.375518616152386, 'min_child_weight': 8}. Best is trial 2 with value: 0.5128205128205128.
# [I 2025-11-15 13:41:10,871] Trial 3 finished with value: 0.47058823529411764 and parameters: {'n_estimators': 526, 'learning_rate': 0.14479323715412012, 'max_depth': 4, 'subsample': 0.777179701030717, 'colsample_bytree': 0.9618042848941044, 'gamma': 3.8132911381174117, 'min_child_weight': 1}. Best is trial 2 with value: 0.5128205128205128.
# [I 2025-11-15 13:41:11,087] Trial 4 finished with value: 0.5152838427947598 and parameters: {'n_estimators': 631, 'learning_rate': 0.29758081418247023, 'max_depth': 4, 'subsample': 0.6194534315607725, 'colsample_bytree': 0.5422580532887882, 'gamma': 3.031351950158863, 'min_child_weight': 4}. Best is trial 4 with value: 0.5152838427947598.
# [I 2025-11-15 13:41:11,256] Trial 5 finished with value: 0.5 and parameters: {'n_estimators': 607, 'learning_rate': 0.27268392889750426, 'max_depth': 8, 'subsample': 0.912177414620432, 'colsample_bytree': 0.9816045065982681, 'gamma': 4.3341466058528235, 'min_child_weight': 3}. Best is trial 4 with value: 0.5152838427947598.
# [I 2025-11-15 13:41:11,371] Trial 6 finished with value: 0.4420289855072464 and parameters: {'n_estimators': 202, 'learning_rate': 0.14503382823837335, 'max_depth': 5, 'subsample': 0.8119760723875376, 'colsample_bytree': 0.5391674507060591, 'gamma': 2.6513337329620716, 'min_child_weight': 4}. Best is trial 4 with value: 0.5152838427947598.
# [I 2025-11-15 13:41:11,583] Trial 7 finished with value: 0.47808764940239046 and parameters: {'n_estimators': 544, 'learning_rate': 0.18200384312937923, 'max_depth': 5, 'subsample': 0.71909426470673, 'colsample_bytree': 0.5017232899902793, 'gamma': 3.2475153872108775, 'min_child_weight': 6}. Best is trial 4 with value: 0.5152838427947598.
# [I 2025-11-15 13:41:11,853] Trial 8 finished with value: 0.6063829787234043 and parameters: {'n_estimators': 586, 'learning_rate': 0.2014206264045303, 'max_depth': 9, 'subsample': 0.9990575845258649, 'colsample_bytree': 0.8781370084389414, 'gamma': 0.21518610932189375, 'min_child_weight': 4}. Best is trial 8 with value: 0.6063829787234043.
# [I 2025-11-15 13:41:11,992] Trial 9 finished with value: 0.5286343612334802 and parameters: {'n_estimators': 269, 'learning_rate': 0.1556337670500496, 'max_depth': 11, 'subsample': 0.5278052234092049, 'colsample_bytree': 0.9144965002555001, 'gamma': 3.984383321671557, 'min_child_weight': 1}. Best is trial 8 with value: 0.6063829787234043.
# [I 2025-11-15 13:41:12,465] Trial 10 finished with value: 0.6195652173913043 and parameters: {'n_estimators': 744, 'learning_rate': 0.2134439500485068, 'max_depth': 8, 'subsample': 0.9797010095170134, 'colsample_bytree': 0.8370223592711298, 'gamma': 0.07702073541927046, 'min_child_weight': 10}. Best is trial 10 with value: 0.6195652173913043.
# [I 2025-11-15 13:41:12,877] Trial 11 finished with value: 0.6292134831460674 and parameters: {'n_estimators': 799, 'learning_rate': 0.2122425951792502, 'max_depth': 8, 'subsample': 0.9882395289582837, 'colsample_bytree': 0.8366108240205682, 'gamma': 0.11432496528726657, 'min_child_weight': 9}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:13,309] Trial 12 finished with value: 0.6292134831460674 and parameters: {'n_estimators': 780, 'learning_rate': 0.23036773747840641, 'max_depth': 7, 'subsample': 0.9818518428066523, 'colsample_bytree': 0.7703942586165211, 'gamma': 0.08133319452096269, 'min_child_weight': 10}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:13,664] Trial 13 finished with value: 0.5700483091787439 and parameters: {'n_estimators': 746, 'learning_rate': 0.2452420438687225, 'max_depth': 6, 'subsample': 0.6884545350422477, 'colsample_bytree': 0.6659954377838689, 'gamma': 1.1122401417248595, 'min_child_weight': 10}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:14,064] Trial 14 finished with value: 0.5514018691588785 and parameters: {'n_estimators': 783, 'learning_rate': 0.23373858662373087, 'max_depth': 7, 'subsample': 0.9397913113078573, 'colsample_bytree': 0.7590047288358117, 'gamma': 1.0388975489081629, 'min_child_weight': 8}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:14,390] Trial 15 finished with value: 0.5742574257425742 and parameters: {'n_estimators': 682, 'learning_rate': 0.24585566637962125, 'max_depth': 9, 'subsample': 0.861727774531484, 'colsample_bytree': 0.6997691709523068, 'gamma': 0.974811542998189, 'min_child_weight': 8}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:15,213] Trial 16 finished with value: 0.4819277108433735 and parameters: {'n_estimators': 687, 'learning_rate': 0.014532179220504399, 'max_depth': 10, 'subsample': 0.9489360924924964, 'colsample_bytree': 0.8257804671746894, 'gamma': 1.665751038004773, 'min_child_weight': 9}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:15,673] Trial 17 finished with value: 0.6270270270270271 and parameters: {'n_estimators': 800, 'learning_rate': 0.17506558208308104, 'max_depth': 7, 'subsample': 0.8484716849355025, 'colsample_bytree': 0.6460778609285897, 'gamma': 0.4121045009305595, 'min_child_weight': 7}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:16,148] Trial 18 finished with value: 0.5363636363636364 and parameters: {'n_estimators': 687, 'learning_rate': 0.10343842306706087, 'max_depth': 6, 'subsample': 0.6686671901301473, 'colsample_bytree': 0.8062402961872659, 'gamma': 1.5729152078188466, 'min_child_weight': 10}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:16,440] Trial 19 finished with value: 0.6031746031746031 and parameters: {'n_estimators': 447, 'learning_rate': 0.21569237993997584, 'max_depth': 12, 'subsample': 0.763871205624868, 'colsample_bytree': 0.7111880120351225, 'gamma': 0.5403689845655498, 'min_child_weight': 6}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:16,688] Trial 20 finished with value: 0.5061224489795918 and parameters: {'n_estimators': 730, 'learning_rate': 0.2624120475837328, 'max_depth': 9, 'subsample': 0.9932666289137964, 'colsample_bytree': 0.9136279414195434, 'gamma': 2.0481767626529312, 'min_child_weight': 9}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:17,026] Trial 21 finished with value: 0.6041666666666666 and parameters: {'n_estimators': 797, 'learning_rate': 0.18270175433442842, 'max_depth': 7, 'subsample': 0.8660795971537257, 'colsample_bytree': 0.6060540485819634, 'gamma': 0.5289959853706945, 'min_child_weight': 7}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:17,382] Trial 22 finished with value: 0.5906735751295337 and parameters: {'n_estimators': 797, 'learning_rate': 0.17838212657985286, 'max_depth': 6, 'subsample': 0.81344455389865, 'colsample_bytree': 0.6364947406177157, 'gamma': 0.5750381929049131, 'min_child_weight': 7}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:17,763] Trial 23 finished with value: 0.6073298429319371 and parameters: {'n_estimators': 659, 'learning_rate': 0.12142692888012246, 'max_depth': 7, 'subsample': 0.9381038436354324, 'colsample_bytree': 0.7878276376377155, 'gamma': 0.2915698592026863, 'min_child_weight': 9}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:18,009] Trial 24 finished with value: 0.5588235294117647 and parameters: {'n_estimators': 722, 'learning_rate': 0.22426718308147955, 'max_depth': 8, 'subsample': 0.9041300379350603, 'colsample_bytree': 0.7209901202993675, 'gamma': 0.9587116182074515, 'min_child_weight': 7}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:18,452] Trial 25 finished with value: 0.6292134831460674 and parameters: {'n_estimators': 753, 'learning_rate': 0.1975887424102557, 'max_depth': 6, 'subsample': 0.9583099636660689, 'colsample_bytree': 0.8644275026602547, 'gamma': 0.06220147160267797, 'min_child_weight': 9}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:18,687] Trial 26 finished with value: 0.5150214592274678 and parameters: {'n_estimators': 743, 'learning_rate': 0.20726887527110505, 'max_depth': 5, 'subsample': 0.9595467350152755, 'colsample_bytree': 0.8704805383939199, 'gamma': 1.390976154167409, 'min_child_weight': 9}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:19,041] Trial 27 finished with value: 0.6187845303867403 and parameters: {'n_estimators': 579, 'learning_rate': 0.2549079902215291, 'max_depth': 6, 'subsample': 0.9169431203881315, 'colsample_bytree': 0.8616979346089532, 'gamma': 0.05311142998011903, 'min_child_weight': 10}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:19,276] Trial 28 finished with value: 0.5686274509803921 and parameters: {'n_estimators': 649, 'learning_rate': 0.20156898198131595, 'max_depth': 10, 'subsample': 0.9772466830847406, 'colsample_bytree': 0.9108894146539029, 'gamma': 0.7778231588111402, 'min_child_weight': 8}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:19,450] Trial 29 finished with value: 0.45018450184501846 and parameters: {'n_estimators': 473, 'learning_rate': 0.23361220986663056, 'max_depth': 3, 'subsample': 0.883417305068157, 'colsample_bytree': 0.7841984537043363, 'gamma': 2.152401201472281, 'min_child_weight': 9}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:19,783] Trial 30 finished with value: 0.47470817120622566 and parameters: {'n_estimators': 386, 'learning_rate': 0.0346083495462053, 'max_depth': 8, 'subsample': 0.8199818485993081, 'colsample_bytree': 0.7339094987893069, 'gamma': 0.03488262149201555, 'min_child_weight': 10}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:20,146] Trial 31 finished with value: 0.6096256684491979 and parameters: {'n_estimators': 762, 'learning_rate': 0.16418972627050862, 'max_depth': 7, 'subsample': 0.8365819547605612, 'colsample_bytree': 0.8284017409185447, 'gamma': 0.506651239198967, 'min_child_weight': 8}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:20,427] Trial 32 finished with value: 0.6203208556149733 and parameters: {'n_estimators': 702, 'learning_rate': 0.19284597769212597, 'max_depth': 7, 'subsample': 0.9478056218920262, 'colsample_bytree': 0.6734138835519697, 'gamma': 0.3807221865281903, 'min_child_weight': 5}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:20,670] Trial 33 finished with value: 0.4838709677419355 and parameters: {'n_estimators': 799, 'learning_rate': 0.13046602782065975, 'max_depth': 6, 'subsample': 0.9990442111809386, 'colsample_bytree': 0.5963245527543062, 'gamma': 1.3087695775509187, 'min_child_weight': 7}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:20,980] Trial 34 finished with value: 0.5959595959595959 and parameters: {'n_estimators': 761, 'learning_rate': 0.17172637785215702, 'max_depth': 5, 'subsample': 0.892821469012403, 'colsample_bytree': 0.7677540300091761, 'gamma': 0.6505567363107889, 'min_child_weight': 9}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:21,181] Trial 35 finished with value: 0.47104247104247104 and parameters: {'n_estimators': 710, 'learning_rate': 0.23245619372687581, 'max_depth': 9, 'subsample': 0.7878190819330729, 'colsample_bytree': 0.9310512914291966, 'gamma': 4.952821576799521, 'min_child_weight': 8}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:21,462] Trial 36 finished with value: 0.6256983240223464 and parameters: {'n_estimators': 770, 'learning_rate': 0.2916362441709065, 'max_depth': 8, 'subsample': 0.9228797622787097, 'colsample_bytree': 0.8448918410144969, 'gamma': 0.314781744394635, 'min_child_weight': 6}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:21,651] Trial 37 finished with value: 0.502127659574468 and parameters: {'n_estimators': 620, 'learning_rate': 0.274714700846822, 'max_depth': 7, 'subsample': 0.970314641567737, 'colsample_bytree': 0.7998563566837033, 'gamma': 1.7580029547367055, 'min_child_weight': 10}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:21,815] Trial 38 finished with value: 0.46153846153846156 and parameters: {'n_estimators': 374, 'learning_rate': 0.19577304856859432, 'max_depth': 3, 'subsample': 0.7329876227847997, 'colsample_bytree': 0.9600643738465207, 'gamma': 0.7952426156168155, 'min_child_weight': 5}. Best is trial 11 with value: 0.6292134831460674.
# [I 2025-11-15 13:41:22,162] Trial 39 finished with value: 0.5686274509803921 and parameters: {'n_estimators': 656, 'learning_rate': 0.14590611086603453, 'max_depth': 4, 'subsample': 0.8866336444192484, 'colsample_bytree': 0.8854011761074398, 'gamma': 0.0005112363946684628, 'min_child_weight': 9}. Best is trial 11 with value: 0.6292134831460674.

# %%
print("Best Trial:", study.best_trial.params)
# Out:
# Best Trial: {'n_estimators': 799, 'learning_rate': 0.2122425951792502, 'max_depth': 8, 'subsample': 0.9882395289582837, 'colsample_bytree': 0.8366108240205682, 'gamma': 0.11432496528726657, 'min_child_weight': 9}

# %%
best_params = study.best_params
best_params["random_state"] = 42
best_params["eval_metric"] = "logloss"
best_params["scale_pos_weight"] = (len(y_train_bin) - y_train_bin.sum()) / y_train_bin.sum()

# %%
best_model = XGBClassifier(**best_params)

# %%
pipeline_best = ImbPipeline(steps=[
    ("scale", preprocessor),
    ("smote", SMOTE(random_state=42)),
    ("model", best_model)
])

# %%
pipeline_best.fit(X_train, y_train_bin)
preds = pipeline_best.predict(X_test)

# %%
print("\n=== Classification Report ===")
print(classification_report(y_test_bin, preds))

print("\n=== Confusion Matrix ===")
print(confusion_matrix(y_test_bin, preds))
# Out:
# === Classification Report ===
#               precision    recall  f1-score   support
#
#            0       0.99      0.97      0.98      1932
#            1       0.51      0.82      0.63        68
#
#     accuracy                           0.97      2000
#    macro avg       0.75      0.90      0.81      2000
# weighted avg       0.98      0.97      0.97      2000
#
#
# === Confusion Matrix ===
# [[1878   54]
#  [  12   56]]
